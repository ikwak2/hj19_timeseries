# %%
import tensorflow as tf

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import Activation, Dense, Dropout
from tensorflow.keras import optimizers
from pandas import Series
import math
import numpy
from tensorflow.keras.layers import *
from tensorflow.keras import layers
import pandas as pd

data = pd.read_csv("nasdaq100_padding.csv")

# %%
data
# Out:
#            AAL     AAPL    ADBE      ADI       ADP       ADSK   AKAM  \
# 0      35.9800   96.800   97.80  61.1500   95.4000  58.180000  58.00
# 1      35.9310   96.890   97.80  61.6100   95.4115  58.190000  58.12
# 2      35.9044   96.950   97.57  61.9800   95.5100  58.203333  57.95
# 3      35.8900   96.970   97.55  62.0900   95.5200  58.216667  57.96
# 4      36.0080   96.960   97.73  61.8900   95.5300  58.230000  58.21
# ...        ...      ...     ...      ...       ...        ...    ...
# 40555  48.5030  115.880  104.19  73.2895  102.2900  74.690000  67.39
# 40556  48.5150  115.875  104.18  73.2900  102.3100  74.675000  67.43
# 40557  48.5300  115.875  104.15  73.2850  102.3200  74.680000  67.40
# 40558  48.5600  115.920  104.19  73.3000  102.3100  74.750000  67.35
# 40559  48.5600  115.910  104.17  73.2900  102.2800  74.740000  67.33
#
#            ALXN     AMAT      AMGN  ...      TXN     VIAB      VOD     VRTX  \
# 0      127.0400  26.6800  165.8100  ...  70.7300  45.2300  31.1701  95.2700
# 1      126.0600  26.7300  165.9101  ...  70.6900  45.0100  31.1900  94.1700
# 2      126.5100  26.7120  166.1800  ...  71.3000  45.0150  31.2100  94.7490
# 3      126.2800  26.7400  166.1480  ...  71.3100  45.0200  31.2100  94.3100
# 4      126.5850  26.7200  165.9900  ...  71.0600  45.0500  31.1800  94.1550
# ...         ...      ...       ...  ...      ...      ...      ...      ...
# 40555  121.1264  32.9200  146.3911  ...  73.8100  34.8100  24.7550  72.1400
# 40556  121.2000  32.9300  146.3951  ...  73.8100  34.7950  24.7597  72.0928
# 40557  121.3500  32.9064  146.3700  ...  73.8001  34.7901  24.7571  72.0600
# 40558  121.3000  32.9200  146.3400  ...  73.8101  34.8200  24.7500  72.0950
# 40559  121.2400  32.9100  146.3100  ...  73.8000  34.8300  24.7500  72.1000
#
#           WBA     WDC    WFM     XLNX     YHOO       NDX
# 0      81.365  52.160  33.95  48.6100  38.0100  4665.054
# 1      81.540  52.150  34.10  48.7400  38.1400  4665.054
# 2      81.530  52.270  34.01  48.9900  38.1500  4665.826
# 3      81.710  52.300  33.96  48.9500  38.1950  4667.081
# 4      81.720  52.300  34.17  48.8900  38.3200  4664.491
# ...       ...     ...    ...      ...      ...       ...
# 40555  84.330  70.230  32.04  59.9200  38.5300  4921.811
# 40556  84.340  70.220  32.03  59.9290  38.5100  4921.580
# 40557  84.350  70.165  32.03  59.9345  38.5084  4921.884
# 40558  84.320  70.210  32.04  59.9400  38.5050  4922.949
# 40559  84.320  70.200  32.01  59.9500  38.5100  4922.942
#
# [40560 rows x 82 columns]

# %%
from sklearn.preprocessing import MinMaxScaler,MaxAbsScaler
values = data[data.columns].values.reshape(-1,82)
values = values.astype('float32')
#scaler = MinMaxScaler(feature_range=(0, 1))
#scaler = MaxAbsScaler()
#scaled = scaler.fit_transform(values)

# %%
prediction_horizon = 1
target = data["NDX"].shift(-prediction_horizon).fillna(method="ffill").values

# %%
train_length = 35100
val_length = 2730
test_length = 2730

X_train = values[:train_length]
X_val = values[train_length:train_length+val_length]
X_test = values[-val_length:]
target_train = target[:train_length]
target_val = target[train_length:train_length+val_length]
target_test = target[-val_length:]

# %%
X_train_max = X_train.max(axis=0)
X_train_min = X_train.min(axis=0)
target_train_max = target_train.max(axis=0)
target_train_min = target_train.min(axis=0)

# %%
X_train = (X_train - X_train_min) / (X_train_max - X_train_min)
X_val = (X_val - X_train_min) / (X_train_max - X_train_min)
X_test = (X_test - X_train_min) / (X_train_max - X_train_min)

target_train = (target_train - target_train_min) / (target_train_max - target_train_min)
target_val = (target_val - target_train_min) / (target_train_max - target_train_min)
target_test = (target_test - target_train_min) / (target_train_max - target_train_min)

# %%
X_train.shape
# Out:
# (35100, 82)

# %%
trainX = np.reshape(X_train, (35080,1, 20, X_train.shape[1]))
valX = np.reshape(X_val, (35080,1, 20,X_val.shape[1]))
testX = np.reshape(X_test, (35080,1,20, X_test.shape[1] ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-282-eb9e278dc3a6> in <module>
# ----> 1 trainX = np.reshape(X_train, (35080,1, 20, X_train.shape[1]))
#       2 valX = np.reshape(X_val, (35080,1, 20,X_val.shape[1]))
#       3 testX = np.reshape(X_test, (35080,1,20, X_test.shape[1] ))
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     299            [5, 6]])
#     300     """
# --> 301     return _wrapfunc(a, 'reshape', newshape, order=order)
#     302
#     303
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 2878200 into shape (35080,1,20,82)

# %%
train_size = 35100
val_size = 2730

test_size = len(scaled) - train_size-val_size
train,val, test = scaled[0:train_size,:],scaled[train_size:train_size+val_size,:], scaled[train_size+val_size:,:]
print(len(train),len(val), len(test))
# Out:
# 35100 2730 2730

# %%
def create_dataset_mul(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back, -1])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %%
look_back = 20
trainX, trainY = create_dataset_mul(X_train, look_back)
valX, valY = create_dataset_mul(X_val, look_back)
testX, testY = create_dataset_mul(X_test, look_back)
# Out:
# 35080
# 2710
# 2710

# %%
trainX.shape
# Out:
# (35080, 20, 82)

# %%
trainX = np.reshape(trainX, (trainX.shape[0],1, trainX.shape[1], trainX.shape[2]))
valX = np.reshape(valX, (valX.shape[0],1, valX.shape[1],valX.shape[2]))
testX = np.reshape(testX, (testX.shape[0],1,testX.shape[1], testX.shape[2] ))

# %%
trainX.shape
# Out:
# (35080, 1, 20, 82)

# %%
first_input = Input(shape=(10,82))

in1=Conv1D(filters=64, kernel_size=5, activation='relu',padding='same')(first_input)
in1= BatchNormalization(scale=False)(in1)

in0=Conv1D(filters=64, kernel_size=3, activation='relu',padding='same')(in1)
in0= BatchNormalization(scale=False)(in0)
#in1=Conv1D(filters=64, kernel_size=3, activation='relu',padding='same')(in0)

in1=Conv1D(filters=64, kernel_size=1, activation='relu',padding='same')(in0)
#in1= BatchNormalization(scale=False)(in1)

#in1=add([in0,in1],name='extractor')
#attn_layer = AttentionLayer(name='attention_layer')
#attn_out, attn_states = attn_layer([in1,in1])

    # Concat attention input and LSTM output, in original code it was decoder LSTM
#concat_out = Concatenate(axis=-1, name='concat_layer')([in1, attn_out])
in1=MaxPooling1D(pool_size=2)(in1)
in1=Flatten()(in1)
in1=Dense(100, activation='relu')(in1)
out=Dense(1)(in1)
model=tf.keras.Model(inputs=[first_input],outputs=[out])
model.compile(optimizer='adam', loss='mse')

checkpoint_path = "saved_weights/nasdaq_1d_.hdf5"
cb = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                        monitor='val_loss',mode='min',
                                                 verbose=1)
# fit model
model.fit(trainX, trainY,validation_data=[valX,valY], epochs=200, verbose=1,callbacks=[cb])
# Out:
# Train on 35090 samples, validate on 2720 samples
# Epoch 1/200
# 34816/35090 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 00001: val_loss improved from inf to 0.02481, saving model to saved_weights/nasdaq_1d_.hdf5
# 35090/35090 [==============================] - 5s 151us/sample - loss: 0.0110 - val_loss: 0.0248
# Epoch 2/200
# 34816/35090 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00002: val_loss improved from 0.02481 to 0.00614, saving model to saved_weights/nasdaq_1d_.hdf5
# 35090/35090 [==============================] - 4s 122us/sample - loss: 0.0016 - val_loss: 0.0061
# Epoch 3/200
# 34944/35090 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00003: val_loss improved from 0.00614 to 0.00322, saving model to saved_weights/nasdaq_1d_.hdf5
# 35090/35090 [==============================] - 4s 123us/sample - loss: 0.0012 - val_loss: 0.0032
# Epoch 4/200
# 34656/35090 [============================>.] - ETA: 0s - loss: 8.6566e-04
# Epoch 00004: val_loss did not improve from 0.00322
# 35090/35090 [==============================] - 4s 121us/sample - loss: 8.6221e-04 - val_loss: 0.0128
# Epoch 5/200
# 34912/35090 [============================>.] - ETA: 0s - loss: 8.2926e-04
# Epoch 00005: val_loss did not improve from 0.00322
# 35090/35090 [==============================] - 4s 122us/sample - loss: 8.2994e-04 - val_loss: 0.0036
# Epoch 6/200
# 34656/35090 [============================>.] - ETA: 0s - loss: 6.4808e-04
# Epoch 00006: val_loss improved from 0.00322 to 0.00072, saving model to saved_weights/nasdaq_1d_.hdf5
# 35090/35090 [==============================] - 4s 121us/sample - loss: 6.4418e-04 - val_loss: 7.2455e-04
# Epoch 7/200
# 34688/35090 [============================>.] - ETA: 0s - loss: 5.3741e-04
# Epoch 00007: val_loss did not improve from 0.00072
# 35090/35090 [==============================] - 4s 121us/sample - loss: 5.3433e-04 - val_loss: 9.9033e-04
# Epoch 8/200
# 35072/35090 [============================>.] - ETA: 0s - loss: 4.5217e-04
# Epoch 00008: val_loss improved from 0.00072 to 0.00070, saving model to saved_weights/nasdaq_1d_.hdf5
# 35090/35090 [==============================] - 4s 123us/sample - loss: 4.5210e-04 - val_loss: 6.9548e-04
# Epoch 9/200
# 34848/35090 [============================>.] - ETA: 0s - loss: 4.1962e-04
# Epoch 00009: val_loss improved from 0.00070 to 0.00020, saving model to saved_weights/nasdaq_1d_.hdf5
# 35090/35090 [==============================] - 4s 121us/sample - loss: 4.1838e-04 - val_loss: 1.9684e-04
# Epoch 10/200
# 34784/35090 [============================>.] - ETA: 0s - loss: 4.1284e-04
# Epoch 00010: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 122us/sample - loss: 4.1116e-04 - val_loss: 2.3234e-04
# Epoch 11/200
# 34848/35090 [============================>.] - ETA: 0s - loss: 3.6115e-04
# Epoch 00011: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 121us/sample - loss: 3.6288e-04 - val_loss: 0.0017
# Epoch 12/200
# 35072/35090 [============================>.] - ETA: 0s - loss: 3.3669e-04
# Epoch 00012: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 122us/sample - loss: 3.3784e-04 - val_loss: 0.0034
# Epoch 13/200
# 34880/35090 [============================>.] - ETA: 0s - loss: 3.0978e-04
# Epoch 00013: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 121us/sample - loss: 3.0909e-04 - val_loss: 0.0011
# Epoch 14/200
# 34784/35090 [============================>.] - ETA: 0s - loss: 2.6601e-04
# Epoch 00014: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 121us/sample - loss: 2.6544e-04 - val_loss: 0.0012
# Epoch 15/200
# 34752/35090 [============================>.] - ETA: 0s - loss: 2.6006e-04
# Epoch 00015: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 120us/sample - loss: 2.6093e-04 - val_loss: 0.0012
# Epoch 16/200
# 34976/35090 [============================>.] - ETA: 0s - loss: 2.1130e-04
# Epoch 00016: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 120us/sample - loss: 2.1087e-04 - val_loss: 4.7855e-04
# Epoch 17/200
# 34784/35090 [============================>.] - ETA: 0s - loss: 2.2728e-04
# Epoch 00017: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 121us/sample - loss: 2.2700e-04 - val_loss: 5.5158e-04
# Epoch 18/200
# 34656/35090 [============================>.] - ETA: 0s - loss: 1.7184e-04
# Epoch 00018: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 120us/sample - loss: 1.7139e-04 - val_loss: 0.0024
# Epoch 19/200
# 34816/35090 [============================>.] - ETA: 0s - loss: 1.7756e-04
# Epoch 00019: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 121us/sample - loss: 1.7695e-04 - val_loss: 0.0012
# Epoch 20/200
# 35008/35090 [============================>.] - ETA: 0s - loss: 1.8493e-04
# Epoch 00020: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 120us/sample - loss: 1.8503e-04 - val_loss: 0.0019
# Epoch 21/200
# 34848/35090 [============================>.] - ETA: 0s - loss: 1.7093e-04
# Epoch 00021: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 121us/sample - loss: 1.7060e-04 - val_loss: 0.0015
# Epoch 22/200
# 34944/35090 [============================>.] - ETA: 0s - loss: 1.6836e-04
# Epoch 00022: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 98us/sample - loss: 1.6846e-04 - val_loss: 7.2141e-04
# Epoch 23/200
# 34464/35090 [============================>.] - ETA: 0s - loss: 1.2995e-04
# Epoch 00023: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 84us/sample - loss: 1.3115e-04 - val_loss: 0.0017
# Epoch 24/200
# 34496/35090 [============================>.] - ETA: 0s - loss: 1.3685e-04
# Epoch 00024: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 84us/sample - loss: 1.3808e-04 - val_loss: 0.0010
# Epoch 25/200
# 34464/35090 [============================>.] - ETA: 0s - loss: 1.4198e-04
# Epoch 00025: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 85us/sample - loss: 1.4184e-04 - val_loss: 0.0013
# Epoch 26/200
# 34816/35090 [============================>.] - ETA: 0s - loss: 1.4079e-04
# Epoch 00026: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 114us/sample - loss: 1.4086e-04 - val_loss: 0.0011
# Epoch 27/200
# 34880/35090 [============================>.] - ETA: 0s - loss: 1.3787e-04
# Epoch 00027: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 95us/sample - loss: 1.3789e-04 - val_loss: 0.0048
# Epoch 28/200
# 34944/35090 [============================>.] - ETA: 0s - loss: 1.2540e-04
# Epoch 00028: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 85us/sample - loss: 1.2527e-04 - val_loss: 0.0045
# Epoch 29/200
# 35008/35090 [============================>.] - ETA: 0s - loss: 1.1689e-04
# Epoch 00029: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 85us/sample - loss: 1.1704e-04 - val_loss: 7.9819e-04
# Epoch 30/200
# 34528/35090 [============================>.] - ETA: 0s - loss: 1.2152e-04
# Epoch 00030: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 86us/sample - loss: 1.2151e-04 - val_loss: 0.0016
# Epoch 31/200
# 34944/35090 [============================>.] - ETA: 0s - loss: 1.2411e-04
# Epoch 00031: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 115us/sample - loss: 1.2382e-04 - val_loss: 0.0063
# Epoch 32/200
# 34880/35090 [============================>.] - ETA: 0s - loss: 1.1947e-04
# Epoch 00032: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 87us/sample - loss: 1.1993e-04 - val_loss: 0.0064
# Epoch 33/200
# 34976/35090 [============================>.] - ETA: 0s - loss: 1.1323e-04
# Epoch 00033: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 95us/sample - loss: 1.1340e-04 - val_loss: 0.0018
# Epoch 34/200
# 34464/35090 [============================>.] - ETA: 0s - loss: 1.1372e-04
# Epoch 00034: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 90us/sample - loss: 1.1318e-04 - val_loss: 0.0052
# Epoch 35/200
# 34624/35090 [============================>.] - ETA: 0s - loss: 1.0385e-04
# Epoch 00035: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 93us/sample - loss: 1.0396e-04 - val_loss: 0.0052
# Epoch 36/200
# 34624/35090 [============================>.] - ETA: 0s - loss: 1.0606e-04
# Epoch 00036: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 93us/sample - loss: 1.0582e-04 - val_loss: 0.0063
# Epoch 37/200
# 34976/35090 [============================>.] - ETA: 0s - loss: 1.0732e-04
# Epoch 00037: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 109us/sample - loss: 1.0722e-04 - val_loss: 0.0044
# Epoch 38/200
# 35040/35090 [============================>.] - ETA: 0s - loss: 9.3261e-05
# Epoch 00038: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 88us/sample - loss: 9.3234e-05 - val_loss: 0.0070
# Epoch 39/200
# 34496/35090 [============================>.] - ETA: 0s - loss: 8.9532e-05
# Epoch 00039: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 84us/sample - loss: 8.9180e-05 - val_loss: 0.0083
# Epoch 40/200
# 34880/35090 [============================>.] - ETA: 0s - loss: 9.7152e-05
# Epoch 00040: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 4s 103us/sample - loss: 9.7217e-05 - val_loss: 0.0072
# Epoch 41/200
# 34816/35090 [============================>.] - ETA: 0s - loss: 9.9137e-05
# Epoch 00041: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 84us/sample - loss: 9.8821e-05 - val_loss: 0.0040
# Epoch 42/200
# 34464/35090 [============================>.] - ETA: 0s - loss: 8.9925e-05
# Epoch 00042: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 85us/sample - loss: 9.0251e-05 - val_loss: 0.0041
# Epoch 43/200
# 34496/35090 [============================>.] - ETA: 0s - loss: 1.1405e-04
# Epoch 00043: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 83us/sample - loss: 1.1359e-04 - val_loss: 0.0068
# Epoch 44/200
# 34688/35090 [============================>.] - ETA: 0s - loss: 9.2312e-05
# Epoch 00044: val_loss did not improve from 0.00020
# 35090/35090 [==============================] - 3s 92us/sample - loss: 9.2814e-05 - val_loss: 0.0037
# Epoch 45/200
# 14464/35090 [===========>..................] - ETA: 1s - loss: 8.5494e-05WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-166-7b6f85add1d5> in <module>
#      30                                                  verbose=1)
#      31 # fit model
# ---> 32 model.fit(trainX, trainY,validation_data=[valX,valY], epochs=200, verbose=1,callbacks=[cb])
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
model.load_weights("saved_weights/nasdaq_1d_.hdf5")

# %%
from matplotlib import pyplot
yhat = model.predict([testX])

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()

# %%
first_input = Input(shape=(None,20,82))

in1=TimeDistributed(LSTM(units =150 , return_sequences=True,recurrent_dropout=0.2))(first_input)

#in1=TimeDistributed(Conv1D(filters=64, kernel_size=7, activation='relu'))(first_input)
#in1= BatchNormalization(scale=False)(in1)
in0=TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(in1)
#in1= BatchNormalization(scale=False)(in0)

in1=TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'))(in1)

#in1=add([in0,in1],name='extractor')
in1=TimeDistributed(MaxPooling1D(pool_size=2,name='extractor'))(in1)

in1=TimeDistributed(Flatten())(in1)
#model.add(LSTM(units = 128, return_sequences=True))
#in1=LSTM(units =50 , return_sequences=False)(in1)
#lstm_out=Bidirectional(LSTM(units =100 , return_sequences=False))(lstm_out)

#attn_layer = AttentionLayer(name='attention_layer')
#attn_out, attn_states = attn_layer([in1, in1])

    # Concat attention input and LSTM output, in original code it was decoder LSTM
#concat_out = Concatenate(axis=-1, name='concat_layer')([in1, attn_out])
#in1=MaxPooling1D(pool_size=2)(in1)

#flat_out = Flatten()(in1)
#flat_out=Dense(20, activation='relu')(flat_out)
#model.add(Dropout(drop_dense))
out1=Dense(1, activation = 'relu')(in1)
model=Model(inputs=first_input, outputs=out1)
model.compile(optimizer='adam', loss='mse')


model.summary()
# Out:
# Model: "model_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_41 (InputLayer)        [(None, None, 20, 82)]    0
# _________________________________________________________________
# time_distributed_137 (TimeDi (None, None, 20, 150)     139800
# _________________________________________________________________
# time_distributed_139 (TimeDi (None, None, 20, 64)      9664
# _________________________________________________________________
# time_distributed_140 (TimeDi (None, None, 10, 64)      0
# _________________________________________________________________
# time_distributed_141 (TimeDi (None, None, 640)         0
# _________________________________________________________________
# dense_48 (Dense)             (None, None, 1)           641
# =================================================================
# Total params: 150,105
# Trainable params: 150,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_path = "saved_weights/timedistribute_nas_lstmcnn_imv.hdf5"
cb = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                        monitor='val_loss',mode='min',
                                                 verbose=1)

# %%
history=model.fit(trainX, trainY, epochs=200, batch_size=100, validation_data=(valX, valY), verbose=1, callbacks=[cb])
# Out:
# Train on 35080 samples, validate on 2710 samples
# Epoch 1/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00001: val_loss improved from inf to 0.02484, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 10s 291us/sample - loss: 0.0037 - val_loss: 0.0248
# Epoch 2/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 5.5974e-04
# Epoch 00002: val_loss improved from 0.02484 to 0.00790, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 9s 243us/sample - loss: 5.6235e-04 - val_loss: 0.0079
# Epoch 3/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 4.1387e-04
# Epoch 00003: val_loss did not improve from 0.00790
# 35080/35080 [==============================] - 8s 241us/sample - loss: 4.1385e-04 - val_loss: 0.0119
# Epoch 4/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 3.3065e-04
# Epoch 00004: val_loss improved from 0.00790 to 0.00601, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 8s 242us/sample - loss: 3.3015e-04 - val_loss: 0.0060
# Epoch 5/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 3.2245e-04
# Epoch 00005: val_loss did not improve from 0.00601
# 35080/35080 [==============================] - 8s 241us/sample - loss: 3.2185e-04 - val_loss: 0.0095
# Epoch 6/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 2.3225e-04
# Epoch 00006: val_loss did not improve from 0.00601
# 35080/35080 [==============================] - 8s 242us/sample - loss: 2.3245e-04 - val_loss: 0.0086
# Epoch 7/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 2.4215e-04
# Epoch 00007: val_loss did not improve from 0.00601
# 35080/35080 [==============================] - 9s 242us/sample - loss: 2.4204e-04 - val_loss: 0.0088
# Epoch 8/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 1.8720e-04
# Epoch 00008: val_loss did not improve from 0.00601
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.8686e-04 - val_loss: 0.0063
# Epoch 9/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.9473e-04
# Epoch 00009: val_loss did not improve from 0.00601
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.9459e-04 - val_loss: 0.0076
# Epoch 10/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 2.1325e-04
# Epoch 00010: val_loss did not improve from 0.00601
# 35080/35080 [==============================] - 8s 242us/sample - loss: 2.1326e-04 - val_loss: 0.0072
# Epoch 11/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 1.5421e-04
# Epoch 00011: val_loss did not improve from 0.00601
# 35080/35080 [==============================] - 9s 243us/sample - loss: 1.5402e-04 - val_loss: 0.0062
# Epoch 12/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 1.7732e-04
# Epoch 00012: val_loss improved from 0.00601 to 0.00581, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 9s 243us/sample - loss: 1.7692e-04 - val_loss: 0.0058
# Epoch 13/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 1.5199e-04
# Epoch 00013: val_loss improved from 0.00581 to 0.00429, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 9s 242us/sample - loss: 1.5469e-04 - val_loss: 0.0043
# Epoch 14/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 1.6318e-04
# Epoch 00014: val_loss did not improve from 0.00429
# 35080/35080 [==============================] - 8s 241us/sample - loss: 1.6315e-04 - val_loss: 0.0064
# Epoch 15/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.3129e-04
# Epoch 00015: val_loss improved from 0.00429 to 0.00346, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 9s 243us/sample - loss: 1.3110e-04 - val_loss: 0.0035
# Epoch 16/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.4072e-04
# Epoch 00016: val_loss improved from 0.00346 to 0.00342, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.4080e-04 - val_loss: 0.0034
# Epoch 17/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 1.4311e-04
# Epoch 00017: val_loss did not improve from 0.00342
# 35080/35080 [==============================] - 9s 243us/sample - loss: 1.4317e-04 - val_loss: 0.0044
# Epoch 18/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 1.1944e-04
# Epoch 00018: val_loss did not improve from 0.00342
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.1952e-04 - val_loss: 0.0040
# Epoch 19/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.2707e-04
# Epoch 00019: val_loss improved from 0.00342 to 0.00264, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 9s 242us/sample - loss: 1.2728e-04 - val_loss: 0.0026
# Epoch 20/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 1.2770e-04
# Epoch 00020: val_loss did not improve from 0.00264
# 35080/35080 [==============================] - 8s 241us/sample - loss: 1.2764e-04 - val_loss: 0.0059
# Epoch 21/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.1543e-04
# Epoch 00021: val_loss did not improve from 0.00264
# 35080/35080 [==============================] - 8s 241us/sample - loss: 1.1535e-04 - val_loss: 0.0041
# Epoch 22/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.3697e-04
# Epoch 00022: val_loss did not improve from 0.00264
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.3688e-04 - val_loss: 0.0030
# Epoch 23/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 1.0907e-04
# Epoch 00023: val_loss did not improve from 0.00264
# 35080/35080 [==============================] - 9s 243us/sample - loss: 1.0905e-04 - val_loss: 0.0029
# Epoch 24/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.1535e-04
# Epoch 00024: val_loss did not improve from 0.00264
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.1535e-04 - val_loss: 0.0039
# Epoch 25/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 1.0557e-04
# Epoch 00025: val_loss did not improve from 0.00264
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.0526e-04 - val_loss: 0.0039
# Epoch 26/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.0850e-04
# Epoch 00026: val_loss improved from 0.00264 to 0.00239, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 9s 243us/sample - loss: 1.0847e-04 - val_loss: 0.0024
# Epoch 27/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 9.9692e-05
# Epoch 00027: val_loss did not improve from 0.00239
# 35080/35080 [==============================] - 8s 242us/sample - loss: 9.9367e-05 - val_loss: 0.0029
# Epoch 28/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 1.1053e-04
# Epoch 00028: val_loss did not improve from 0.00239
# 35080/35080 [==============================] - 9s 243us/sample - loss: 1.1067e-04 - val_loss: 0.0034
# Epoch 29/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 1.0091e-04
# Epoch 00029: val_loss did not improve from 0.00239
# 35080/35080 [==============================] - 8s 241us/sample - loss: 1.0071e-04 - val_loss: 0.0028
# Epoch 30/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 9.2122e-05
# Epoch 00030: val_loss improved from 0.00239 to 0.00216, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 9s 242us/sample - loss: 9.2183e-05 - val_loss: 0.0022
# Epoch 31/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 9.0269e-05
# Epoch 00031: val_loss improved from 0.00216 to 0.00197, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 8s 242us/sample - loss: 9.0223e-05 - val_loss: 0.0020
# Epoch 32/200
# 34800/35080 [============================>.] - ETA: 0s - loss: 9.7443e-05
# Epoch 00032: val_loss did not improve from 0.00197
# 35080/35080 [==============================] - 8s 241us/sample - loss: 9.7469e-05 - val_loss: 0.0022
# Epoch 33/200
# 34900/35080 [============================>.] - ETA: 0s - loss: 8.7905e-05
# Epoch 00033: val_loss did not improve from 0.00197
# 35080/35080 [==============================] - 8s 242us/sample - loss: 8.7701e-05 - val_loss: 0.0033
# Epoch 34/200
# 35000/35080 [============================>.] - ETA: 0s - loss: 1.1194e-04
# Epoch 00034: val_loss improved from 0.00197 to 0.00183, saving model to saved_weights/timedistribute_nas_lstmcnn_imv.hdf5
# 35080/35080 [==============================] - 8s 242us/sample - loss: 1.1183e-04 - val_loss: 0.0018
# Epoch 35/200
# 13400/35080 [==========>...................] - ETA: 4s - loss: 1.0129e-04

# %%
model.load_weights("saved_weights/timedistribute_nas_lstmcnn_imv.hdf5")

# %%
from matplotlib import pyplot
yhat = model.predict([valX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(valY, label='true')
pyplot.legend()
pyplot.show()

# %%
from math import *
rmse = sqrt(mean_squared_error(valY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.00348

# %%
from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))


pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')

pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)
# Out:
# Test RMSE: 0.09168
# Test MAE: 0.08991
# Test MSE: 0.00840

# %%
from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')

pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)
# Out:
# Test RMSE: 4.72999
# Test MAE: 3.95179
# Test MSE: 22.37284

# %%
plt.figure(figsize=(20,10))

pyplot.plot(yhat_inverse, label='predict')
pyplot.plot(testY_inverse, label='true')

pyplot.legend()
pyplot.show()

# %% [markdown]
# ### attention cnn, cnn, rescnn 순서

# %%
from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 2.78804

# %%
from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 5.21353

# %%
from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01849

# %%
from tensorflow.keras.models import Model


def gradient_importance(seq, model):

    seq = tf.Variable(seq[np.newaxis,:,:], dtype=tf.float32)

    with tf.GradientTape() as tape:
        predictions = model(seq)

    grads = tape.gradient(predictions, seq)
    grads = tf.reduce_mean(grads, axis=1).numpy()[0]
    
    return grads



def activation_grad(seq, model):
    
    seq = seq[np.newaxis,:,:]
    grad_model = Model([model.inputs], 
                       [model.get_layer('extractor').output, 
                        model.output])

    # Obtain the predicted value and the intermediate filters
    with tf.GradientTape() as tape:
        seq_outputs, predictions = grad_model(seq)

    # Extract filters and gradients
    output = seq_outputs[0]
    grads = tape.gradient(predictions, seq_outputs)[0]

    # Average gradients spatially
    weights = tf.reduce_mean(grads, axis=0)
    
    # Get a ponderated map of filters according to grad importance
    cam = np.ones(output.shape[0], dtype=np.float32)
    for index, w in enumerate(weights):
        cam += w * output[:, index]

    time = int(seq.shape[1]/output.shape[0])
    cam = zoom(cam.numpy(), time, order=1)
    heatmap = (cam - cam.min())/(cam.max() - cam.min())
    
    return heatmap

# %%
from scipy.ndimage import zoom
import random
id_=random.randint(0,len(testX))


X_test=testX.copy()
activation = activation_grad(X_test[id_], model)

plt.figure(figsize=(9,5))
plt.plot(X_test[id_])
#plt.plot(yhat, label='predict')
#plt.plot(testY, label='true')
plt.ylabel('std series'); plt.xlabel('time lags'); #plt.title(pd.to_datetime(test_date[sequence_length+id_]))
plt.twinx()
#plt.xticks(a)
plt.imshow(np.vstack([activation]*30), alpha=0.35)
plt.axis('off'); plt.colorbar()
np.set_printoptions(False)

# %%
columns=data.columns[5:]

grad_imp = gradient_importance(X_test[id_], model)

plt.figure(figsize=(5,5))
plt.bar(range(len(grad_imp)), grad_imp)
plt.xticks(range(len(columns)), columns, rotation=90)
plt.ylabel('gradients'); #plt.title(pd.to_datetime(test_date[sequence_length+id_]))
np.set_printoptions(False)
