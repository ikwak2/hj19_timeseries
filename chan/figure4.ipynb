# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas.api.types import CategoricalDtype
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

# %%
bike_multistep = pd.read_csv("C:\\Users\\cksgn_000\\jupyter notebook\\time\\chan\\Graph\\Predicted value\\csv\\bike_multistep.csv")
bike_multistep_1 = pd.read_csv("C:\\Users\\cksgn_000\\jupyter notebook\\time\chan\\Graph\\Predicted value\\csv\\bike_multistep_1.csv")
btc_multistep = pd.read_csv("C:\\Users\\cksgn_000\\jupyter notebook\\time\chan\\Graph\\Predicted value\\csv\\btc_multistep.csv")
btc_multistep_1 = pd.read_csv("C:\\Users\\cksgn_000\\jupyter notebook\\time\chan\\Graph\\Predicted value\\csv\\btc_multistep_1.csv")
pm2_5_multistep = pd.read_csv("C:\\Users\\cksgn_000\\jupyter notebook\\time\chan\\Graph\\Predicted value\\csv\\pm2.5_multistep.csv")
pm2_5_multistep_1 = pd.read_csv("C:\\Users\\cksgn_000\\jupyter notebook\\time\chan\\Graph\\Predicted value\\csv\\pm2.5_multistep_1.csv")

# %%
bike_multistep
# Out:
#     Time  yhat_inverse  testY_inverse
# 0      0    351.436127     379.000000
# 1      1    334.743347     387.000000
# 2      2    292.567261     214.000000
# 3      3    223.492523     175.000000
# 4      4    152.320038     119.000008
# 5      5     17.605482      99.000008
# 6      6    114.104576     115.000008
# 7      7    392.002685     339.000000
# 8      8    879.556213     819.000000
# 9      9   1310.863525    1524.000000
# 10    10    749.671509     795.000000
# 11    11    549.476562     586.000000
# 12    12    601.941223     643.000000
# 13    13    793.688354     752.000000
# 14    14    796.838379     718.000000
# 15    15    780.712463     796.000000
# 16    16    912.428650     794.000000
# 17    17    925.413208     935.000000
# 18    18   1228.311768    1156.000000
# 19    19   1606.133911    1708.000000
# 20    20   1219.836670    1181.000000
# 21    21    989.747986     943.000000
# 22    22    965.944214     955.000000
# 23    23    866.362793     846.000000

# %%
ggplot(data=bike_multistep, mapping=aes(x='Time',y='yhat_inverse')) +geom_point()
# Out:
# <ggplot: (11535491548)>

# %% [markdown]
# ## bike_multistep

# %%
ggplot(data = bike_multistep) + geom_line(mapping=aes(x='Time',y='yhat_inverse'), colour="orange", size=0.7) + geom_line(mapping=aes(x='Time',y='testY_inverse'),colour="skyblue", size=0.7) + theme_bw() + theme(panel_grid = element_blank(), text = element_text(size = 12)) + ylab('Bike')
# Out:
# <ggplot: (11537820398)>

# %% [markdown]
# ## bike_multistep_1

# %%
ggplot(data = bike_multistep_1) + geom_line(mapping=aes(x='Time',y='yhat_inverse'), colour="orange", size=0.7) + geom_line(mapping=aes(x='Time',y='testY_inverse'),colour="skyblue", size=0.7) + theme_bw() + theme(panel_grid = element_blank(), text = element_text(size = 12)) + ylab('Bike')
# Out:
# <ggplot: (11537263261)>

# %% [markdown]
# ## btc_multistep

# %%
ggplot(data = btc_multistep) + geom_line(mapping=aes(x='Time',y='yhat_inverse'), colour="orange", size=0.7) + geom_line(mapping=aes(x='Time',y='testY_inverse'),colour="skyblue", size=0.7) + theme_bw() + theme(panel_grid = element_blank(), text = element_text(size = 12)) + ylab('Bike')
# Out:
# <ggplot: (11537449409)>

# %% [markdown]
# ## btc_multistep_1

# %%
ggplot(data = btc_multistep_1) + geom_line(mapping=aes(x='Time',y='yhat_inverse'), colour="orange", size=0.7) + geom_line(mapping=aes(x='Time',y='testY_inverse'),colour="skyblue", size=0.7) + theme_bw() + theme(panel_grid = element_blank(), text = element_text(size = 12)) + ylab('Bike')
# Out:
# <ggplot: (11539036094)>

# %% [markdown]
# ## pm2_5_multistep

# %%
ggplot(data = pm2_5_multistep) + geom_line(mapping=aes(x='Time',y='yhat_inverse'), colour="orange", size=0.7) + geom_line(mapping=aes(x='Time',y='testY_inverse'),colour="skyblue", size=0.7) + theme_bw() + theme(panel_grid = element_blank(), text = element_text(size = 12)) + ylab('Bike')
# Out:
# <ggplot: (11537114998)>

# %% [markdown]
# ## pm2_5_multistep_1

# %%
ggplot(data = pm2_5_multistep_1) + geom_line(mapping=aes(x='Time',y='yhat_inverse'), colour="orange", size=0.7) + geom_line(mapping=aes(x='Time',y='testY_inverse'),colour="skyblue", size=0.7) + theme_bw() + theme(panel_grid = element_blank(), text = element_text(size = 12)) + ylab('Bike')
# Out:
# <ggplot: (11535792225)>
