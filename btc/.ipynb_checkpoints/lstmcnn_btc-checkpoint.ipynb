# %%
import tensorflow as tf

import numpy as np

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import Activation, Dense, Dropout
from tensorflow.keras import optimizers
from pandas import Series
import math
import numpy
from tensorflow.keras.layers import *
from tensorflow.keras import layers
import pandas as pd

#data = pd.read_csv('bitcoin.csv')
data = pd.read_csv('bitcoin2000.csv')

# %%
data.set_index(['timeUTC'],inplace=True)
#data = data['item_cnt_day'].resample('D').sum()
df=pd.DataFrame(data)

# %%
len(data)
# Out:
# 10005

# %%
from sklearn.preprocessing import MinMaxScaler
values = data[['close','high','low','open']].values.reshape(-1,4)
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
np.max(values)
# Out:
# 41964.96

# %%
train_size = int(len(scaled) * 0.80)
val_size = int(len(scaled) * 0.10)

test_size = len(scaled) - train_size-val_size
train,val, test = scaled[0:train_size,:],scaled[train_size:train_size+val_size,:], scaled[train_size+val_size:,:]
print(len(train),len(val), len(test))
# Out:
# 8004 1000 1001

# %%
def create_dataset_mul(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %%
look_back = 12
trainX, trainY = create_dataset_mul(train, look_back)
valX, valY = create_dataset_mul(val, look_back)
testX, testY = create_dataset_mul(test, look_back)
# Out:
# 7992
# 988
# 989

# %% [raw]
# X_train_min, X_train_max = trainX.min(axis=0), trainX.max(axis=0)
# y_train_min, y_train_max = trainY.min(axis=0), trainY.max(axis=0)

# %% [raw]
# trainX = (trainX - X_train_min)/(X_train_max - X_train_min+ 1e-9 )
# valX= (valX - X_train_min)/(X_train_max - X_train_min+ 1e-9 )
# testX = (testX - X_train_min)/(X_train_max - X_train_min+ 1e-9 )
# trainY = (trainY - y_train_min)/(y_train_max - y_train_min + 1e-9)
# valY = (valY - y_train_min)/(y_train_max - y_train_min+ 1e-9 )
# testY = (testY - y_train_min)/(y_train_max - y_train_min+ 1e-9 )

# %%
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_out_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>', U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)
            if verbose:
                print('Ws+Uh>', Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
first_input = Input(shape=(12,4))

in1=Conv1D(filters=64, kernel_size=5, activation='relu',padding='same')(first_input)
#in1= BatchNormalization(scale=False)(in1)

in0=Conv1D(filters=64, kernel_size=3, activation='relu',padding='same')(in1)
#in1= BatchNormalization(scale=False)(in0)
#in1=Conv1D(filters=64, kernel_size=3, activation='relu',padding='same')(in0)

in1=Conv1D(filters=64, kernel_size=1, activation='relu',padding='same')(in1)
#in1= BatchNormalization(scale=False)(in1)

#in1=add([in0,in1],name='extractor')
#attn_layer = AttentionLayer(name='attention_layer')
#attn_out, attn_states = attn_layer([in1,in1])

    # Concat attention input and LSTM output, in original code it was decoder LSTM
#concat_out = Concatenate(axis=-1, name='concat_layer')([in1, attn_out])
in1=MaxPooling1D(pool_size=2)(in1)
in1=Flatten()(in1)
#in1=Dense(100, activation='relu')(in1)
out=Dense(1)(in1)
model=tf.keras.Model(inputs=[first_input],outputs=[out])
model.compile(optimizer='adam', loss='mse')

model.summary()

checkpoint_path = "saved_weights/btc.hdf5"
cb = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                        monitor='val_loss',mode='min',
                                                 verbose=1)
# fit model

# fit model9
#history=model.fit(trainX, trainY, epochs=200, batch_size=100, validation_data=(valX, valY), verbose=1, callbacks=[cb])
# Out:
# Model: "model_184"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_187 (InputLayer)       [(None, 12, 4)]           0
# _________________________________________________________________
# conv1d_522 (Conv1D)          (None, 12, 64)            1344
# _________________________________________________________________
# conv1d_524 (Conv1D)          (None, 12, 64)            4160
# _________________________________________________________________
# max_pooling1d_76 (MaxPooling (None, 6, 64)             0
# _________________________________________________________________
# flatten_155 (Flatten)        (None, 384)               0
# _________________________________________________________________
# dense_144 (Dense)            (None, 1)                 385
# =================================================================
# Total params: 5,889
# Trainable params: 5,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(trainX, trainY, epochs=200, batch_size=100, validation_data=(valX, valY), verbose=1, callbacks=[cb])
# Out:
# Train on 7992 samples, validate on 988 samples
# Epoch 1/200
# 6600/7992 [=======================>......] - ETA: 0s - loss: 7.5505e-04
# Epoch 00001: val_loss improved from inf to 0.00015, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 1s 76us/sample - loss: 6.2592e-04 - val_loss: 1.5192e-04
# Epoch 2/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 1.1128e-05
# Epoch 00002: val_loss improved from 0.00015 to 0.00008, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 1.1111e-05 - val_loss: 7.9037e-05
# Epoch 3/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 1.0174e-05
# Epoch 00003: val_loss improved from 0.00008 to 0.00006, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 9.8943e-06 - val_loss: 5.9120e-05
# Epoch 4/200
# 6700/7992 [========================>.....] - ETA: 0s - loss: 8.5934e-06
# Epoch 00004: val_loss did not improve from 0.00006
# 7992/7992 [==============================] - 0s 26us/sample - loss: 8.7374e-06 - val_loss: 5.9563e-05
# Epoch 5/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 7.7321e-06
# Epoch 00005: val_loss improved from 0.00006 to 0.00005, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 7.8063e-06 - val_loss: 4.6427e-05
# Epoch 6/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 6.5484e-06
# Epoch 00006: val_loss improved from 0.00005 to 0.00005, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 6.8364e-06 - val_loss: 4.5701e-05
# Epoch 7/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 6.5668e-06
# Epoch 00007: val_loss did not improve from 0.00005
# 7992/7992 [==============================] - 0s 27us/sample - loss: 6.4143e-06 - val_loss: 4.7806e-05
# Epoch 8/200
# 6400/7992 [=======================>......] - ETA: 0s - loss: 6.2264e-06
# Epoch 00008: val_loss did not improve from 0.00005
# 7992/7992 [==============================] - 0s 26us/sample - loss: 6.0560e-06 - val_loss: 5.2138e-05
# Epoch 9/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 7.3620e-06
# Epoch 00009: val_loss did not improve from 0.00005
# 7992/7992 [==============================] - 0s 27us/sample - loss: 6.9662e-06 - val_loss: 4.8588e-05
# Epoch 10/200
# 6400/7992 [=======================>......] - ETA: 0s - loss: 5.7070e-06
# Epoch 00010: val_loss did not improve from 0.00005
# 7992/7992 [==============================] - 0s 27us/sample - loss: 5.5105e-06 - val_loss: 5.0039e-05
# Epoch 11/200
# 6400/7992 [=======================>......] - ETA: 0s - loss: 5.1134e-06
# Epoch 00011: val_loss improved from 0.00005 to 0.00004, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 5.3971e-06 - val_loss: 4.2221e-05
# Epoch 12/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 5.2090e-06
# Epoch 00012: val_loss improved from 0.00004 to 0.00004, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 5.1521e-06 - val_loss: 3.8505e-05
# Epoch 13/200
# 6400/7992 [=======================>......] - ETA: 0s - loss: 5.4995e-06
# Epoch 00013: val_loss did not improve from 0.00004
# 7992/7992 [==============================] - 0s 26us/sample - loss: 5.2300e-06 - val_loss: 4.7121e-05
# Epoch 14/200
# 6100/7992 [=====================>........] - ETA: 0s - loss: 5.2370e-06
# Epoch 00014: val_loss improved from 0.00004 to 0.00004, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 5.2426e-06 - val_loss: 3.5678e-05
# Epoch 15/200
# 6600/7992 [=======================>......] - ETA: 0s - loss: 5.3820e-06
# Epoch 00015: val_loss improved from 0.00004 to 0.00003, saving model to saved_weights/btc.hdf5
# 7992/7992 [==============================] - 0s 28us/sample - loss: 5.3483e-06 - val_loss: 3.3676e-05
# Epoch 16/200
# 6200/7992 [======================>.......] - ETA: 0s - loss: 4
val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 26us/sample - loss: 3.1509e-06 - val_loss: 6.5942e-05
# Epoch 195/200
# 6700/7992 [========================>.....] - ETA: 0s - loss: 2.9241e-06
# Epoch 00195: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 26us/sample - loss: 2.8761e-06 - val_loss: 7.4284e-05
# Epoch 196/200
# 6600/7992 [=======================>......] - ETA: 0s - loss: 3.0510e-06
# Epoch 00196: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 26us/sample - loss: 3.0576e-06 - val_loss: 5.7581e-05
# Epoch 197/200
# 6600/7992 [=======================>......] - ETA: 0s - loss: 2.7145e-06
# Epoch 00197: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 26us/sample - loss: 2.8884e-06 - val_loss: 4.3904e-05
# Epoch 198/200
# 6400/7992 [=======================>......] - ETA: 0s - loss: 3.2588e-06
# Epoch 00198: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 26us/sample - loss: 3.1305e-06 - val_loss: 5.6140e-05
# Epoch 199/200
# 6500/7992 [=======================>......] - ETA: 0s - loss: 3.1444e-06
# Epoch 00199: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 26us/sample - loss: 3.4120e-06 - val_loss: 2.2578e-05
# Epoch 200/200
# 6700/7992 [========================>.....] - ETA: 0s - loss: 3.7011e-06
# Epoch 00200: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 26us/sample - loss: 3.5866e-06 - val_loss: 3.0198e-05

# %%
model.load_weights("saved_weights/btc.hdf5")

# %%
from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)


rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.5f' % mae)
# Out:
# Test RMSE: 0.02473
# Test MAE: 0.02104
# Test MSE: 0.00061
# Test RMSE: 940.10245
# Test MAE: 799.91840

# %%
from tensorflow.keras.models import *

first_input = Input(shape=(None,12,4))

in1=TimeDistributed(LSTM(units =150 , return_sequences=True))(first_input)

in1=TimeDistributed(Conv1D(filters=64, kernel_size=5, activation='relu'))(in1)
#in1= BatchNormalization(scale=False)(in1)
#in0=TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(in1)
#in1= BatchNormalization(scale=False)(in0)

in1=TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'))(in1)

#in1=add([in0,in1],name='extractor')
in1=TimeDistributed(MaxPooling1D(pool_size=2,name='extractor'))(in1)

in1=TimeDistributed(Flatten())(in1)
#model.add(LSTM(units = 128, return_sequences=True))
#in1=LSTM(units =50 , return_sequences=False)(in1)
#lstm_out=Bidirectional(LSTM(units =100 , return_sequences=False))(lstm_out)

#attn_layer = AttentionLayer(name='attention_layer')
#attn_out, attn_states = attn_layer([in1, in1])

    # Concat attention input and LSTM output, in original code it was decoder LSTM
#concat_out = Concatenate(axis=-1, name='concat_layer')([in1, attn_out])
#in1=MaxPooling1D(pool_size=2)(in1)

#flat_out = Flatten()(in1)
#flat_out=Dense(20, activation='relu')(flat_out)
#model.add(Dropout(drop_dense))
out1=Dense(1, activation = 'relu')(in1)
model=Model(inputs=first_input, outputs=out1)
model.compile(optimizer='adam', loss='mse')

checkpoint_path = "saved_weights/timedistribute_btc_1dcnn51_1.hdf5"
cb = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                        monitor='val_loss',mode='min',
                                                 verbose=1)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 12, 4)]     0
# _________________________________________________________________
# time_distributed (TimeDistri (None, None, 12, 150)     93000
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, None, 8, 64)       48064
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, None, 8, 64)       4160
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, None, 4, 64)       0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, None, 256)         0
# _________________________________________________________________
# dense (Dense)                (None, None, 1)           257
# =================================================================
# Total params: 145,481
# Trainable params: 145,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
trainX = np.reshape(trainX, (trainX.shape[0],1, trainX.shape[1], trainX.shape[2]))
valX = np.reshape(valX, (valX.shape[0],1, valX.shape[1],valX.shape[2]))
testX = np.reshape(testX, (testX.shape[0],1,testX.shape[1], testX.shape[2] ))

# %%
checkpoint_path = "saved_weights/timedistribute_btc_1dcnn51_1.hdf5"
cb = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                        monitor='val_loss',mode='min',
                                                 verbose=1)

# %%
## timedistribute lstm(100)-1dcnn

history=model.fit(trainX, trainY, epochs=200, batch_size=100, validation_data=(valX, valY), verbose=1, callbacks=[cb])
# Out:
# Train on 7992 samples, validate on 988 samples
# Epoch 1/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0391e-06
# Epoch 00001: val_loss improved from inf to 0.00002, saving model to saved_weights/timedistribute_btc_1dcnn51_1.hdf5
# 7992/7992 [==============================] - 1s 131us/sample - loss: 3.0143e-06 - val_loss: 1.6094e-05
# Epoch 2/200
# 7500/7992 [===========================>..] - ETA: 0s - loss: 3.8859e-06
# Epoch 00002: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.7913e-06 - val_loss: 2.4501e-05
# Epoch 3/200
# 7500/7992 [===========================>..] - ETA: 0s - loss: 3.8174e-06
# Epoch 00003: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 129us/sample - loss: 3.7700e-06 - val_loss: 2.9513e-05
# Epoch 4/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0089e-06
# Epoch 00004: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.0857e-06 - val_loss: 2.8911e-05
# Epoch 5/200
# 7500/7992 [===========================>..] - ETA: 0s - loss: 3.1974e-06
# Epoch 00005: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.2178e-06 - val_loss: 1.6579e-05
# Epoch 6/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.1138e-06
# Epoch 00006: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.0563e-06 - val_loss: 1.7432e-05
# Epoch 7/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.3089e-06
# Epoch 00007: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.4023e-06 - val_loss: 1.8769e-05
# Epoch 8/200
# 7500/7992 [===========================>..] - ETA: 0s - loss: 3.1659e-06
# Epoch 00008: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.1010e-06 - val_loss: 1.8137e-05
# Epoch 9/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.1468e-06
# Epoch 00009: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.1720e-06 - val_loss: 1.8154e-05
# Epoch 10/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.4950e-06
# Epoch 00010: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.4483e-06 - val_loss: 1.7607e-05
# Epoch 11/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0925e-06
# Epoch 00011: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 127us/sample - loss: 3.1358e-06 - val_loss: 2.6093e-05
# Epoch 12/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.1633e-06
# Epoch 00012: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.2419e-06 - val_loss: 2.3806e-05
# Epoch 13/200
# 7500/7992 [===========================>..] - ETA: 0s - loss: 3.6649e-06
# Epoch 00013: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.5588e-06 - val_loss: 2.3942e-05
# Epoch 14/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.1919e-06
# Epoch 00014: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.1565e-06 - val_loss: 3.2955e-05
# Epoch 15/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0889e-06
# Epoch 00015: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.0551e-06 - val_loss: 1.6198e-05
# Epoch 16/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.2423e-06
# Epoch 00016: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 127us/sample - loss: 3.2869e-06 - val_loss: 1.7769e-05
# Epoch 17/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.2112e-06
# Epoch 00017: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 127us/sample - loss: 3.2066e-06 - val_loss: 2.9751e-05
# Epoch 18/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.8772e-06
# Epoch 00018: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.7902e-06 - val_loss: 1.6417e-05
# Epoch 19/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0854e-06
# Epoch 00019: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.1947e-06 - val_loss: 1.8312e-05
# Epoch 20/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.2040e-06
# Epoch 00020: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 132us/sample - loss: 3.2687e-06 - val_loss: 1.9204e-05
# Epoch 21/200
# 7700/7992 [===========================>..] - ETA: 0s - loss: 3.1714e-06
# Epoch 00021: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 132us/sample - loss: 3.2431e-06 - val_loss: 1.7176e-05
# Epoch 22/200
# 7800/7992 [============================>.] - ETA: 0s - loss: 3.3639e-06
# Epoch 00022: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 130us/sample - loss: 3
val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.0436e-06 - val_loss: 1.5763e-05
# Epoch 189/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0132e-06
# Epoch 00189: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 2.9949e-06 - val_loss: 1.8133e-05
# Epoch 190/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 2.8873e-06
# Epoch 00190: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 129us/sample - loss: 2.8899e-06 - val_loss: 2.3252e-05
# Epoch 191/200
# 7800/7992 [============================>.] - ETA: 0s - loss: 3.2211e-06
# Epoch 00191: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 130us/sample - loss: 3.1944e-06 - val_loss: 1.6415e-05
# Epoch 192/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0599e-06
# Epoch 00192: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.0894e-06 - val_loss: 1.9038e-05
# Epoch 193/200
# 7500/7992 [===========================>..] - ETA: 0s - loss: 3.1051e-06
# Epoch 00193: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 130us/sample - loss: 3.1122e-06 - val_loss: 2.4505e-05
# Epoch 194/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.0531e-06
# Epoch 00194: val_loss improved from 0.00002 to 0.00002, saving model to saved_weights/timedistribute_btc_1dcnn51_1.hdf5
# 7992/7992 [==============================] - 1s 131us/sample - loss: 3.0497e-06 - val_loss: 1.5488e-05
# Epoch 195/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.5320e-06
# Epoch 00195: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 128us/sample - loss: 3.5352e-06 - val_loss: 3.1075e-05
# Epoch 196/200
# 7500/7992 [===========================>..] - ETA: 0s - loss: 3.0928e-06
# Epoch 00196: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 129us/sample - loss: 3.0620e-06 - val_loss: 1.7790e-05
# Epoch 197/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 3.1239e-06
# Epoch 00197: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 129us/sample - loss: 3.1338e-06 - val_loss: 1.9599e-05
# Epoch 198/200
# 7600/7992 [===========================>..] - ETA: 0s - loss: 2.8516e-06
# Epoch 00198: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 129us/sample - loss: 2.9463e-06 - val_loss: 1.5507e-05
# Epoch 199/200
# 7900/7992 [============================>.] - ETA: 0s - loss: 2.8911e-06
# Epoch 00199: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 130us/sample - loss: 2.9229e-06 - val_loss: 1.5764e-05
# Epoch 200/200
# 7900/7992 [============================>.] - ETA: 0s - loss: 2.9997e-06
# Epoch 00200: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 1s 133us/sample - loss: 3.0020e-06 - val_loss: 1.5513e-05

# %%
model.load_weights("saved_weights/timedistribute_btc_1dcnn51_1.hdf5")

# %%
###1cnn(5,1) ,saved_weights/timedistribute_btc_1dcnn51_.hdf5

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)

plt.figure(figsize=(20,10))

pyplot.plot(yhat_inverse, label='predict')
pyplot.plot(testY_inverse,'r', label='true')
pyplot.legend()
pyplot.show()

rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.5f' % mae)
# Out:
# Test RMSE: 0.01294
# Test MAE: 0.00884
# Test MSE: 0.00017
# Test RMSE: 491.96025
# Test MAE: 335.99310

# %%
###1cnn(5,1) ,saved_weights/timedistribute_btc_1dcnn51_.hdf5

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)


rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.5f' % mae)
# Out:
# Test RMSE: 0.01299
# Test MAE: 0.00890
# Test MSE: 0.00017
# Test RMSE: 493.78536
# Test MAE: 338.32248

# %%
###1cnn(5,1) 

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)


rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.5f' % mae)
# Out:
# Test RMSE: 0.02058
# Test MAE: 0.01528
# Test MSE: 0.00042
# Test RMSE: 782.37407
# Test MAE: 580.90405

# %%
###1cnn(5,3,1) 

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)


rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.5f' % mae)
# Out:
# Test RMSE: 0.01884
# Test MAE: 0.01356
# Test MSE: 0.00035
# Test RMSE: 716.13308
# Test MAE: 515.68689

# %%
###lstm(150)-cnn(5,1) 

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)


rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.5f' % mae)
# Out:
# Test RMSE: 0.01428
# Test MAE: 0.00976
# Test MSE: 0.00020
# Test RMSE: 542.88281
# Test MAE: 370.95142

# %%
###lstm(100)-cnn(3,1) timedistribute_btc_lstmcnn200.hdf5

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)

rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.3f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.3f' % mae)
# Out:
# Test RMSE: 0.01606
# Test MAE: 0.01150
# Test MSE: 0.00026
# Test RMSE: 610.565
# Test MAE: 437.246

# %%
###lstm(200)-cnn(3,1) 

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)

rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.3f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.3f' % mae)
# Out:
# Test RMSE: 0.01627
# Test MAE: 0.01129
# Test MSE: 0.00026
# Test RMSE: 618.511
# Test MAE: 429.252

# %%
###lstm(150)-cnn(5,1) timedistribute_btc_lstmcnn150.hdf5

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)

rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.3f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.3f' % mae)
# Out:
# Test RMSE: 0.01439
# Test MAE: 0.01045
# Test MSE: 0.00021
# Test RMSE: 546.957
# Test MAE: 397.323

# %%
###lstm(200)-cnn(3,1) timedistribute_btc_lstmcnn150.hdf5

from matplotlib import pyplot
from sklearn.metrics import *

yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)

mae = mean_absolute_error(testY, yhat)
print('Test MAE: %.5f' % mae)

mse = mean_squared_error(testY, yhat)
print('Test MSE: %.5f' % mse)

yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)
testY_inverse=testY*(np.max(values)-np.min(values))+np.min(values)

rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.3f' % rmse)

mae = mean_absolute_error(yhat_inverse, testY_inverse)
print('Test MAE: %.3f' % mae)

# %%
## lstm(200)-cnn(2layer),saved_weights/timedistribute_btc_lstmcnn1.hdf5

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
##lstm(200)-cnn(5,1),saved_weights/timedistribute_btc_lstmcnn1.hdf5

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01630

# %%
## lstm(200)-cnn(2layer),saved_weights/timedistribute_btc_lstmcnn.hdf5

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01800

# %%
## bilstm(200)-cnn

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.02062

# %%
## lstm(200)-cnn

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
## lstm(100)-cnn

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01749

# %%
from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.02240

# %%
trainX = np.reshape(trainX, (trainX.shape[0],1, trainX.shape[1], trainX.shape[2]))
valX = np.reshape(valX, (valX.shape[0],1, valX.shape[1],valX.shape[2]))
testX = np.reshape(testX, (testX.shape[0],1,testX.shape[1], testX.shape[2] ))

# %%
## timedistribute 1dcnn
history=model.fit(trainX, trainY, epochs=200, batch_size=100, validation_data=(valX, valY), verbose=1, callbacks=[cb])
# Out:
# Train on 7992 samples, validate on 988 samples
# Epoch 1/200
# 6200/7992 [======================>.......] - ETA: 0s - loss: 7.7190e-04
# Epoch 00001: val_loss improved from inf to 0.00010, saving model to saved_weights/timedistribute_btc.hdf5
# 7992/7992 [==============================] - 1s 85us/sample - loss: 6.0198e-04 - val_loss: 9.6665e-05
# Epoch 2/200
# 6100/7992 [=====================>........] - ETA: 0s - loss: 1.3050e-05
# Epoch 00002: val_loss improved from 0.00010 to 0.00009, saving model to saved_weights/timedistribute_btc.hdf5
# 7992/7992 [==============================] - 0s
val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.5633e-06 - val_loss: 2.9533e-05
# Epoch 189/200
# 6000/7992 [=====================>........] - ETA: 0s - loss: 3.5530e-06
# Epoch 00189: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.7363e-06 - val_loss: 5.0344e-05
# Epoch 190/200
# 6200/7992 [======================>.......] - ETA: 0s - loss: 4.5146e-06
# Epoch 00190: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 29us/sample - loss: 4.3908e-06 - val_loss: 2.6430e-05
# Epoch 191/200
# 6100/7992 [=====================>........] - ETA: 0s - loss: 3.7354e-06
# Epoch 00191: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.6200e-06 - val_loss: 3.1968e-05
# Epoch 192/200
# 6000/7992 [=====================>........] - ETA: 0s - loss: 3.5278e-06
# Epoch 00192: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 29us/sample - loss: 3.5096e-06 - val_loss: 2.1225e-05
# Epoch 193/200
# 6000/7992 [=====================>........] - ETA: 0s - loss: 4.2062e-06
# Epoch 00193: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 29us/sample - loss: 3.9086e-06 - val_loss: 3.9005e-05
# Epoch 194/200
# 6300/7992 [======================>.......] - ETA: 0s - loss: 4.2304e-06
# Epoch 00194: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.9199e-06 - val_loss: 2.1424e-05
# Epoch 195/200
# 6300/7992 [======================>.......] - ETA: 0s - loss: 3.7801e-06
# Epoch 00195: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.6905e-06 - val_loss: 1.9260e-05
# Epoch 196/200
# 6100/7992 [=====================>........] - ETA: 0s - loss: 4.1693e-06
# Epoch 00196: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 4.0666e-06 - val_loss: 1.9343e-05
# Epoch 197/200
# 6200/7992 [======================>.......] - ETA: 0s - loss: 3.7522e-06
# Epoch 00197: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.6510e-06 - val_loss: 1.9551e-05
# Epoch 198/200
# 6300/7992 [======================>.......] - ETA: 0s - loss: 3.9203e-06
# Epoch 00198: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.8142e-06 - val_loss: 3.1549e-05
# Epoch 199/200
# 6300/7992 [======================>.......] - ETA: 0s - loss: 4.0419e-06
# Epoch 00199: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.9731e-06 - val_loss: 4.1446e-05
# Epoch 200/200
# 6200/7992 [======================>.......] - ETA: 0s - loss: 3.7792e-06
# Epoch 00200: val_loss did not improve from 0.00002
# 7992/7992 [==============================] - 0s 28us/sample - loss: 3.6204e-06 - val_loss: 2.1061e-05

# %%
model.load_weights("saved_weights/timedistribute_btc.hdf5")

# %%
from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
##timedistribute 1dcnn

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01644

# %%
##1d

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
##timedistribute cnn

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
##timedistribute cnn

from matplotlib import pyplot
yhat = model.predict([testX])
yhat=yhat.reshape(-1,1)
plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
#Res1d

from matplotlib import pyplot
yhat = model.predict([testX])

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %%
##attn1d

from matplotlib import pyplot
yhat = model.predict([testX])

plt.figure(figsize=(20,10))

pyplot.plot(yhat, label='predict')
pyplot.plot(testY,'r', label='true')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ### res1d, cnn, attention1d

# %%
##1d

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01901

# %%
##res1d

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01418

# %%
##timedistribute

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01931

# %%
##timedistribute

from math import *
rmse = sqrt(mean_squared_error(testY, yhat))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.01601

# %%
from tensorflow.keras.models import Model


def gradient_importance(seq, model):

    seq = tf.Variable(seq[np.newaxis,:,:], dtype=tf.float32)

    with tf.GradientTape() as tape:
        predictions = model(seq)

    grads = tape.gradient(predictions, seq)
    grads = tf.reduce_mean(grads, axis=1).numpy()[0]
    
    return grads



def activation_grad(seq, model):
    
    seq = seq[np.newaxis,:,:]
    grad_model = Model([model.inputs], 
                       [model.get_layer('extractor').output, 
                        model.output])

    # Obtain the predicted value and the intermediate filters
    with tf.GradientTape() as tape:
        seq_outputs, predictions = grad_model(seq)

    # Extract filters and gradients
    output = seq_outputs[0]
    grads = tape.gradient(predictions, seq_outputs)[0]

    # Average gradients spatially
    weights = tf.reduce_mean(grads, axis=0)
    
    # Get a ponderated map of filters according to grad importance
    cam = np.ones(output.shape[0], dtype=np.float32)
    for index, w in enumerate(weights):
        cam += w * output[:, index]

    time = int(seq.shape[1]/output.shape[0])
    cam = zoom(cam.numpy(), time, order=1)
    heatmap = (cam - cam.min())/(cam.max() - cam.min())
    
    return heatmap

# %%
from scipy.ndimage import zoom
import random
id_=random.randint(0,len(testX))


X_test=testX.copy()
activation = activation_grad(X_test[id_], model)

plt.figure(figsize=(9,5))
plt.plot(X_test[id_])
#plt.plot(yhat, label='predict')
#plt.plot(testY, label='true')
plt.ylabel('std series'); plt.xlabel('time lags'); #plt.title(pd.to_datetime(test_date[sequence_length+id_]))
plt.twinx()
#plt.xticks(a)
plt.imshow(np.vstack([activation]*30), alpha=0.35)
plt.axis('off'); plt.colorbar()
np.set_printoptions(False)

# %%
columns='close','high','low','open','volumefrom'

grad_imp = gradient_importance(X_test[id_], model)

plt.figure(figsize=(5,5))
plt.bar(range(len(grad_imp)), grad_imp)
plt.xticks(range(len(columns)), columns, rotation=90)
plt.ylabel('gradients'); #plt.title(pd.to_datetime(test_date[sequence_length+id_]))
np.set_printoptions(False)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Dense, Activation, Dropout, Lambda, Multiply, Add, Concatenate
from tensorflow.keras.optimizers import Adam

# convolutional operation parameters
n_filters = 32 # 32 
filter_width = 2
dilation_rates = [2**i for i in range(8)] * 2 

# define an input history series and pass it through a stack of dilated causal convolution blocks. 
history_seq = Input(shape=(6, 3))
x = history_seq

skips = []
for dilation_rate in dilation_rates:
    
    # preprocessing - equivalent to time-distributed dense
    x = Conv1D(16, 1, padding='same', activation='relu')(x) 
    
    # filter convolution
    x_f = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # gating convolution
    x_g = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # multiply filter and gating branches
    z = Multiply()([Activation('tanh')(x_f),
                    Activation('sigmoid')(x_g)])
    
    # postprocessing - equivalent to time-distributed dense
    z = Conv1D(16, 1, padding='same', activation='relu')(z)
    
    # residual connection
    x = Add()([x, z])    
    
    # collect skip connections
    skips.append(z)

# add all skip connection outputs 
out = Activation('relu')(Add()(skips))

# final time-distributed dense layers 
out = Conv1D(128, 1, padding='same')(out)
out = Activation('relu')(out)
out = Dropout(.2)(out)
out = Conv1D(1, 1, padding='same')(out)

# extract the last 60 time steps as the training target
def slice(x, seq_length):
    return x[:,-seq_length:,:]

pred_seq_train = Lambda(slice, arguments={'seq_length':60})(out)

model = Model(history_seq, pred_seq_train)
model.compile(Adam(), loss='mean_absolute_error')

# %%
model.summary()
# Out:
# Model: "model_41"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_73 (InputLayer)           [(None, 6, 3)]       0
# __________________________________________________________________________________________________
# conv1d_300 (Conv1D)             (None, 6, 16)        64          input_73[0][0]
# __________________________________________________________________________________________________
# conv1d_301 (Conv1D)             (None, 6, 32)        1056        conv1d_300[0][0]
# __________________________________________________________________________________________________
# conv1d_302 (Conv1D)             (None, 6, 32)        1056        conv1d_300[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 6, 32)        0           conv1d_301[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 6, 32)        0           conv1d_302[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 6, 32)        0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# conv1d_303 (Conv1D)             (None, 6, 16)        528         multiply_32[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 6, 16)        0           conv1d_300[0][0]
#                                                                  conv1d_303[0][0]
# __________________________________________________________________________________________________
# conv1d_304 (Conv1D)             (None, 6, 16)        272         add_34[0][0]
# __________________________________________________________________________________________________
# conv1d_305 (Conv1D)             (None, 6, 32)        1056        conv1d_304[0][0]
# __________________________________________________________________________________________________
# conv1d_306 (Conv1D)             (None, 6, 32)        1056        conv1d_304[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 6, 32)        0           conv1d_305[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 6, 32)        0           conv1d_306[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 6, 32)        0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# conv1d_307 (Conv1D)             (None, 6, 16)        528         multiply_33[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 6, 16)        0           conv1d_304[0][0]
#                                                                  conv1d_307[0][0]
# __________________________________________________________________________________________________
# conv1d_308 (Conv1D)             (None, 6, 16)        272         add_35[0][0]
# __________________________________________________________________________________________________
# conv1d_309 (Conv1D)             (None, 6, 32)        1056        conv1d_308[0][0]
# __________________________________________________________________________________________________
# conv1d_310 (Conv1D)             (None, 6, 32)        1056        conv1d_308[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 6, 32)        0           conv1d_309[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 6, 32)        0           conv1d_310[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 6, 32)        0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# conv1d_311 (Conv1D)             (None, 6, 16)        528         multiply_34[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 6, 16)        0           conv1d_308[0][0]
#                                                                  conv1d_311[0][0]
# __________________________________________________________________________________________________
# conv1d_312 (Conv1D)             (None, 6, 16)        272         add_36[0][0]
# __________________________________________________________________________________________________
# conv1d_313 (Conv1D)             (None, 6, 32)        1056        conv1d_312[0][0]
# __________________________________________________________________________________________________
# conv1d_314 (Conv1D)             (None, 6, 32)        1056        conv1d_312[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 6, 32)        0           conv1d_313[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 6, 32)        0           conv1d_314[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 6, 32)        0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# conv1d_315 (Conv1D)             (None, 6, 16)        528         multiply_35[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 6, 16)        0           conv1d_312[0][0]
#                                                                  conv1d_315[0][0]
# __________________________________________________________________________________________________
# conv1d_316 (Conv1D)             (None, 6, 16)        272         add_37[0][0]
# __________________________________________________________________________________________________
# conv1d_317 (Conv1D)             (None, 6, 32)        1056        conv1d_316[0][0]
# __________________________________________________________________________________________________
# conv1d_318 (Conv1D)             (None, 6, 32)        1056        conv1d_316[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 6, 32)        0           conv1d_317[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 6, 32)        0           conv1d_318[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 6, 32)        0           activation_76[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# conv1d_319 (Conv1D)             (None, 6, 16)        528         multiply_36[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 6, 16)        0           conv1d_316[0][0]
#                                                                  conv1d_319[0][0]
# __________________________________________________________________________________________________
# conv1d_320 (Conv1D)             (None, 6, 16)        272         add_38[0][0]
# __________________________________________________________________________________________________
# conv1d_321 (Conv1D)             (None, 6, 32)        1056        conv1d_320[0][0]
# __________________________________________________________________________________________________
# conv1d_322 (Conv1D)             (None, 6, 32)        1056        conv1d_320[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 6, 32)        0           conv1d_321[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 6, 32)        0           conv1d_322[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 6, 32)        0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# conv1d_323 (Conv1D)             (None, 6, 16)        528         multiply_37[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 6, 16)        0           conv1d_320[0][0]
#                                                                  conv1d_323[0][0]
# __________________________________________________________________________________________________
# conv1d_324 (Conv1D)             (None, 6, 16)        272         add_39[0][0]
# __________________________________________________________________________________________________
# conv1d_325 (Conv1D)             (None, 6, 32)        1056        conv1d_324[0][0]
# __________________________________________________________________________________________________
# conv1d_326 (Conv1D)             (None, 6, 32)        1056        conv1d_324[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 6, 32)        0           conv1d_325[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 6, 32)        0           conv1d_326[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 6, 32)        0           activation_80[0][0]
#                                                                  activation_81[0][0]
# __________________________________________________________________________________________________
# conv1d_327 (Conv1D)             (None, 6, 16)        528         multiply_38[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 6, 16)        0           conv1d_324[0][0]
#                                                                  conv1d_327[0][0]
# __________________________________________________________________________________________________
# conv1d_328 (Conv1D)             (None, 6, 16)        272         add_40[0][0]
# __________________________________________________________________________________________________
# conv1d_329 (Conv1D)             (None, 6, 32)        1056        conv1d_328[0][0]
# __________________________________________________________________________________________________
# conv1d_330 (Conv1D)             (None, 6, 32)        1056        conv1d_328[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 6, 32)        0           conv1d_329[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 6, 32)        0           conv1d_330[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 6, 32)        0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# conv1d_331 (Conv1D)             (None, 6, 16)        528         multiply_39[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 6, 16)        0           conv1d_328[0][0]
#                                                                  conv1d_331[0][0]
# __________________________________________________________________________________________________
# conv1d_332 (Conv1D)             (None, 6, 16)        272         add_41[0][0]
# __________________________________________________________________________________________________
# conv1d_333 (Conv1D)             (None, 6, 32)        1056        conv1d_332[0][0]
# __________________________________________________________________________________________________
# conv1d_334 (Conv1D)             (None, 6, 32)        1056        conv1d_332[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 6, 32)        0           conv1d_333[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 6, 32)        0           conv1d_334[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 6, 32)        0           activation_84[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv1d_335 (Conv1D)             (None, 6, 16)        528         multiply_40[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 6, 16)        0           conv1d_332[0][0]
#                                                                  conv1d_335[0][0]
# __________________________________________________________________________________________________
# conv1d_336 (Conv1D)             (None, 6, 16)        272         add_42[0][0]
# __________________________________________________________________________________________________
# conv1d_337 (Conv1D)             (None, 6, 32)        1056        conv1d_336[0][0]
# __________________________________________________________________________________________________
# conv1d_338 (Conv1D)             (None, 6, 32)        1056        conv1d_336[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 6, 32)        0           conv1d_337[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 6, 32)        0           conv1d_338[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 6, 32)        0           activation_86[0][0]
#                                                                  activation_87[0][0]
# __________________________________________________________________________________________________
# conv1d_339 (Conv1D)             (None, 6, 16)        528         multiply_41[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 6, 16)        0           conv1d_336[0][0]
#                                                                  conv1d_339[0][0]
# __________________________________________________________________________________________________
# conv1d_340 (Conv1D)             (None, 6, 16)        272         add_43[0][0]
# __________________________________________________________________________________________________
# conv1d_341 (Conv1D)             (None, 6, 32)        1056        conv1d_340[0][0]
# __________________________________________________________________________________________________
# conv1d_342 (Conv1D)             (None, 6, 32)        1056        conv1d_340[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 6, 32)        0           conv1d_341[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 6, 32)        0           conv1d_342[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 6, 32)        0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# conv1d_343 (Conv1D)             (None, 6, 16)        528         multiply_42[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 6, 16)        0           conv1d_340[0][0]
#                                                                  conv1d_343[0][0]
# __________________________________________________________________________________________________
# conv1d_344 (Conv1D)             (None, 6, 16)        272         add_44[0][0]
# __________________________________________________________________________________________________
# conv1d_345 (Conv1D)             (None, 6, 32)        1056        conv1d_344[0][0]
# __________________________________________________________________________________________________
# conv1d_346 (Conv1D)             (None, 6, 32)        1056        conv1d_344[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 6, 32)        0           conv1d_345[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 6, 32)        0           conv1d_346[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 6, 32)        0           activation_90[0][0]
#                                                                  activation_91[0][0]
# __________________________________________________________________________________________________
# conv1d_347 (Conv1D)             (None, 6, 16)        528         multiply_43[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 6, 16)        0           conv1d_344[0][0]
#                                                                  conv1d_347[0][0]
# __________________________________________________________________________________________________
# conv1d_348 (Conv1D)             (None, 6, 16)        272         add_45[0][0]
# __________________________________________________________________________________________________
# conv1d_349 (Conv1D)             (None, 6, 32)        1056        conv1d_348[0][0]
# __________________________________________________________________________________________________
# conv1d_350 (Conv1D)             (None, 6, 32)        1056        conv1d_348[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 6, 32)        0           conv1d_349[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 6, 32)        0           conv1d_350[0][0]
# __________________________________________________________________________________________________
# multiply_44 (Multiply)          (None, 6, 32)        0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# conv1d_351 (Conv1D)             (None, 6, 16)        528         multiply_44[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 6, 16)        0           conv1d_348[0][0]
#                                                                  conv1d_351[0][0]
# __________________________________________________________________________________________________
# conv1d_352 (Conv1D)             (None, 6, 16)        272         add_46[0][0]
# __________________________________________________________________________________________________
# conv1d_353 (Conv1D)             (None, 6, 32)        1056        conv1d_352[0][0]
# __________________________________________________________________________________________________
# conv1d_354 (Conv1D)             (None, 6, 32)        1056        conv1d_352[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 6, 32)        0           conv1d_353[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 6, 32)        0           conv1d_354[0][0]
# __________________________________________________________________________________________________
# multiply_45 (Multiply)          (None, 6, 32)        0           activation_94[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# conv1d_355 (Conv1D)             (None, 6, 16)        528         multiply_45[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 6, 16)        0           conv1d_352[0][0]
#                                                                  conv1d_355[0][0]
# __________________________________________________________________________________________________
# conv1d_356 (Conv1D)             (None, 6, 16)        272         add_47[0][0]
# __________________________________________________________________________________________________
# conv1d_357 (Conv1D)             (None, 6, 32)        1056        conv1d_356[0][0]
# __________________________________________________________________________________________________
# conv1d_358 (Conv1D)             (None, 6, 32)        1056        conv1d_356[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 6, 32)        0           conv1d_357[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 6, 32)        0           conv1d_358[0][0]
# __________________________________________________________________________________________________
# multiply_46 (Multiply)          (None, 6, 32)        0           activation_96[0][0]
#                                                                  activation_97[0][0]
# __________________________________________________________________________________________________
# conv1d_359 (Conv1D)             (None, 6, 16)        528         multiply_46[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 6, 16)        0           conv1d_356[0][0]
#                                                                  conv1d_359[0][0]
# __________________________________________________________________________________________________
# conv1d_360 (Conv1D)             (None, 6, 16)        272         add_48[0][0]
# __________________________________________________________________________________________________
# conv1d_361 (Conv1D)             (None, 6, 32)        1056        conv1d_360[0][0]
# __________________________________________________________________________________________________
# conv1d_362 (Conv1D)             (None, 6, 32)        1056        conv1d_360[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 6, 32)        0           conv1d_361[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 6, 32)        0           conv1d_362[0][0]
# __________________________________________________________________________________________________
# multiply_47 (Multiply)          (None, 6, 32)        0           activation_98[0][0]
#                                                                  activation_99[0][0]
# __________________________________________________________________________________________________
# conv1d_363 (Conv1D)             (None, 6, 16)        528         multiply_47[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 6, 16)        0           conv1d_303[0][0]
#                                                                  conv1d_307[0][0]
#                                                                  conv1d_311[0][0]
#                                                                  conv1d_315[0][0]
#                                                                  conv1d_319[0][0]
#                                                                  conv1d_323[0][0]
#                                                                  conv1d_327[0][0]
#                                                                  conv1d_331[0][0]
#                                                                  conv1d_335[0][0]
#                                                                  conv1d_339[0][0]
#                                                                  conv1d_343[0][0]
#                                                                  conv1d_347[0][0]
#                                                                  conv1d_351[0][0]
#                                                                  conv1d_355[0][0]
#                                                                  conv1d_359[0][0]
#                                                                  conv1d_363[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 6, 16)        0           add_50[0][0]
# __________________________________________________________________________________________________
# conv1d_364 (Conv1D)             (None, 6, 128)       2176        activation_100[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 6, 128)       0           conv1d_364[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 6, 128)       0           activation_101[0][0]
# __________________________________________________________________________________________________
# conv1d_365 (Conv1D)             (None, 6, 1)         129         dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 6, 1)         0           conv1d_365[0][0]
# ==================================================================================================
# Total params: 48,689
# Trainable params: 48,689
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(Xtrain,Ytrain,validation_data=(Xtest,Ytest), epochs=100)
# Out:
# Train on 8000 samples, validate on 1999 samples
# Epoch 1/100
# 8000/8000 [==============================] - 7s 890us/sample - loss: 0.0118 - val_loss: 0.0298
# Epoch 2/100
# 8000/8000 [==============================] - 3s 432us/sample - loss: 0.0066 - val_loss: 0.0214
# Epoch 3/100
# 8000/8000 [==============================] - 3s 433us/sample - loss: 0.0052 - val_loss: 0.0186
# Epoch 4/100
# 8000/8000 [==============================] - 3s 433us/sample - loss: 0.0045 - val_loss: 0.0286
# Epoch 5/100
# 8000/8000 [==============================] - 3s 433us/sample - loss: 0.0044 - val_loss: 0.0250
# Epoch 6/100
# 8000/8000 [==============================] - 3s 432us/sample - loss: 0.0042 - val_loss: 0.0205
# Epoch 35/100
# 8000/8000 [==============================] - 3s 434us/sample - loss: 0.0037 - val_loss: 0.0124
# Epoch 36/100
# 8000/8000 [==============================] - 3s 431us/sample - loss: 0.0038 - val_loss: 0.0121
# Epoch 37/100
# 8000/8000 [==============================] - 3s 436us/sample - loss: 0.0038 - val_loss: 0.0122
# Epoch 38/100
# 8000/8000 [==============================] - 4s 442us/sample - loss: 0.0037 - val_loss: 0.0165
# Epoch 39/100
# 8000/8000 [==============================] - 4s 440us/sample - loss: 0.0037 - val_loss: 0.0125
# Epoch 40/100
# 8000/8000 [==============================] - 3s 435us/sample - loss: 0.0038 - val_loss: 0.0130
# Epoch 41/100
# 8000/8000 [==============================] - 4s 448us/sample - loss: 0.0038 - val_loss: 0.0116
# Epoch 42/100
# 8000/8000 [==============================] - 4s 452us/sample - loss: 0.0037 - val_loss: 0.0117
# Epoch 43/100
# 8000/8000 [==============================] - 3s 430us/sample - loss: 0.0037 - val_loss: 0.0130
# Epoch 44/100
# 8000/8000 [==============================] - 4s 440us/sample - loss: 0.0037 - val_loss: 0.0137
# Epoch 45/100
# 8000/8000 [==============================] - 4s 446us/sample - loss: 0.0038 - val_loss: 0.0126
# Epoch 46/100
# 8000/8000 [==============================] - 4s 440us/sample - loss: 0.0037 - val_loss: 0.0140
# Epoch 47/100
# 8000/8000 [==============================] - 4s 446us/sample - loss: 0.0038 - val_loss: 0.0106
# Epoch 48/100
# 8000/8000 [==============================] - 3s 437us/sample - loss: 0.0037 - val_loss: 0.0114
# Epoch 49/100
# 8000/8000 [==============================] - 3s 430us/sample - loss: 0.0037 - val_loss: 0.0105
# Epoch 50/100
# 8000/8000 [==============================] - 4s 448us/sample - loss: 0.0038 - val_loss: 0.0106
# Epoch 51/100
# 8000/8000 [==============================] - 4s 439us/sample - loss: 0.0037 - val_loss: 0.0110
# Epoch 52/100
# 8000/8000 [==============================] - 3s 430us/sample - loss: 0.0037 - val_loss: 0.0107
# Epoch 53/100
# 8000/8000 [==============================] - 3s 436us/sample - loss: 0.0037 - val_loss: 0.0103
# Epoch 54/100
# 8000/8000 [==============================] - 4s 466us/sample - loss: 0.0037 - val_loss: 0.0183
# Epoch 55/100
# 8000/8000 [==============================] - 3s 437us/sample - loss: 0.0037 - val_loss: 0.0112
# Epoch 56/100
#   32/8000 [..............................] - ETA: 3s - loss: 0.0043
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-266-0705301df182> in <module>
# ----> 1 model.fit(Xtrain,Ytrain,validation_data=(Xtest,Ytest), epochs=100)
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
date_to_index = pd.Series(index=pd.Index([pd.to_datetime(c) for c in df.columns[1:]]),
                          data=[i for i in range(len(df.columns[1:]))])

series_array = df[df.columns[1:]].values

def get_time_block_series(series_array, date_to_index, start_date, end_date):
    
    inds = date_to_index[start_date:end_date]
    return series_array[:,inds]

def transform_series_encode(series_array):
    
    series_array = np.log1p(np.nan_to_num(series_array)) # filling NaN with 0
    series_mean = series_array.mean(axis=1).reshape(-1,1) 
    series_array = series_array - series_mean
    series_array = series_array.reshape((series_array.shape[0],series_array.shape[1], 1))
    
    return series_array, series_mean

def transform_series_decode(series_array, encode_series_mean):
    
    series_array = np.log1p(np.nan_to_num(series_array)) # filling NaN with 0
    series_array = series_array - encode_series_mean
    series_array = series_array.reshape((series_array.shape[0],series_array.shape[1], 1))
    
    return series_array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-19-a9f43c5a6b26> in <module>
# ----> 1 date_to_index = pd.Series(index=pd.Index([pd.to_datetime(c) for c in df.columns[1:]]),
#       2                           data=[i for i in range(len(df.columns[1:]))])
#       3
#       4 series_array = df[df.columns[1:]].values
#       5
#
# <ipython-input-19-a9f43c5a6b26> in <listcomp>(.0)
# ----> 1 date_to_index = pd.Series(index=pd.Index([pd.to_datetime(c) for c in df.columns[1:]]),
#       2                           data=[i for i in range(len(df.columns[1:]))])
#       3
#       4 series_array = df[df.columns[1:]].values
#       5
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     794             result = convert_listlike(arg, box, format)
#     795     else:
# --> 796         result = convert_listlike(np.array([arg]), box, format)[0]
#     797
#     798     return result
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     461             errors=errors,
#     462             require_iso8601=require_iso8601,
# --> 463             allow_object=True,
#     464         )
#     465
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1982             return values.view("i8"), tz_parsed
#    1983         except (ValueError, TypeError):
# -> 1984             raise e
#    1985
#    1986     if tz_parsed is not None:
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1973             dayfirst=dayfirst,
#    1974             yearfirst=yearfirst,
# -> 1975             require_iso8601=require_iso8601,
#    1976         )
#    1977     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/anaconda3/envs/spoof/lib/python3.5/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#     651         if len(res) == 0:
#
# ParserError: Unknown string format: high

# %%
first_n_samples = 120000
batch_size = 2**11
epochs = 10

# sample of series from train_enc_start to train_enc_end  
encoder_input_data = get_time_block_series(series_array, date_to_index, 
                                           train_enc_start, train_enc_end)[:first_n_samples]
encoder_input_data, encode_series_mean = transform_series_encode(encoder_input_data)

# sample of series from train_pred_start to train_pred_end 
decoder_target_data = get_time_block_series(series_array, date_to_index, 
                                            train_pred_start, train_pred_end)[:first_n_samples]
decoder_target_data = transform_series_decode(decoder_target_data, encode_series_mean)

# we append a lagged history of the target series to the input data, 
# so that we can train with teacher forcing
lagged_target_history = decoder_target_data[:,:-1,:1]
encoder_input_data = np.concatenate([encoder_input_data, lagged_target_history], axis=1)

model.compile(Adam(), loss='mean_absolute_error')
history = model.fit(encoder_input_data, decoder_target_data,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e326cb04d902> in <module>
#       4
#       5 # sample of series from train_enc_start to train_enc_end
# ----> 6 encoder_input_data = get_time_block_series(series_array, date_to_index,
#       7                                            train_enc_start, train_enc_end)[:first_n_samples]
#       8 encoder_input_data, encode_series_mean = transform_series_encode(encoder_input_data)
#
# NameError: name 'get_time_block_series' is not defined

# %%
first_input = Input(shape=(1,backView))
#simpleRNN1 = layers.LSTM(units=64,bias_initializer= initializers.RandomNormal(stddev=0.0001),
#                           activation="relu",kernel_initializer= "random_uniform")(first_input)
simpleRNN1=layers.LSTM(256, return_sequences=True)(first_input)
simpleRNN1=layers.LSTM(128, return_sequences=False)(simpleRNN1)
#simpleRNN1=layers.Bidirectional(LSTM(512, return_sequences=False))(simpleRNN1)


second_input = Input(shape=(1,backView))

simpleRNN2=layers.LSTM(256, return_sequences=True)(second_input)
simpleRNN2=LSTM(128, return_sequences=False)(simpleRNN2)

#simpleRNN2=Bidirectional(LSTM(128, return_sequences=False))(simpleRNN2)

#simpleRNN2=layers.Dense(256, activation='relu')(simpleRNN2)

#concatenate two layers,stack dense layer on top
concat_lay = tf.keras.layers.Concatenate()([simpleRNN1, simpleRNN2]) 
#concat_lay=Dropout(0.7)(concat_lay)
dens_lay = layers.Dense(128, activation='relu')(concat_lay)
#dens_lay=Dropout(0.7)(dens_lay)
dens_lay = layers.Dense(32, activation='relu')(dens_lay)
dens_lay = layers.Dense(1)(dens_lay)
model = tf.keras.Model(inputs=[first_input,second_input], outputs= [dens_lay])
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
model.fit([trainX1,trainX2],[trainY1,trainY2], epochs=50, batch_size=32, shuffle = False)

# %%
first_input = Input(shape=(6,1))
in1=layers.Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(6, 1))(first_input)
in2=layers.Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(6, 1))(in1)
in3=layers.Conv1D(filters=128, kernel_size=1, activation='relu')(in2)
in4=layers.MaxPooling1D(pool_size=2)(in3)
in5=layers.Flatten()(in4)
in6=layers.Dense(100)(in5)
#in6=layers.Dense(1)(in6)

second_input=Input(shape=(6,1))
#in11=layers.Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(6, 1))(second_input)
#in22=layers.Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(6, 1))(in11)
#in33=layers.Conv1D(filters=128, kernel_size=1, activation='relu')(in22)
##in44=layers.MaxPooling1D(pool_size=2)(in33)
#in55=layers.Flatten()(in44)
in11=layers.Bidirectional(LSTM(100))(second_input)

concat=layers.Concatenate()([in6, in11])
dens=layers.Dense(100,activation='relu')(concat)
dens=layers.Dense(1)(concat)

model=tf.keras.Model(inputs=[first_input,second_input],outputs=[dens])
model.compile(optimizer='adam', loss='mse')

# %%
second_input=Input(shape=(6,3))
in11=layers.Conv1D(filters=32, kernel_size=3,padding='same', activation='relu', input_shape=(6, 3))(second_input)
in11=layers.MaxPooling1D(pool_size=2)(in11)

in22=layers.Conv1D(filters=32, kernel_size=3,padding='same', activation='relu')(in11)
#in33=layers.Conv1D(filters=32, kernel_size=1, activation='relu')(in22)
in44=layers.MaxPooling1D(pool_size=2)(in22)
in44=TimeDistributed(Flatten())(in44)

#in55=layers.Flatten()(in44)
in11=layers.Bidirectional(LSTM(100,return_sequences=True))(in44)
#in11=layers.Bidirectional(LSTM(30))(in11)
#concat=layers.Concatenate()([in6, in11])
dens=layers.Dense(100,activation='relu')(in11)
dens=layers.Dense(1)(dens)

model=tf.keras.Model(inputs=second_input,outputs=dens)
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "model_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_70 (InputLayer)        [(None, 6, 3)]            0
# _________________________________________________________________
# conv1d_166 (Conv1D)          (None, 6, 32)             320
# _________________________________________________________________
# max_pooling1d_80 (MaxPooling (None, 3, 32)             0
# _________________________________________________________________
# conv1d_167 (Conv1D)          (None, 3, 32)             3104
# _________________________________________________________________
# max_pooling1d_81 (MaxPooling (None, 1, 32)             0
# _________________________________________________________________
# time_distributed_32 (TimeDis (None, 1, 32)             0
# _________________________________________________________________
# bidirectional_37 (Bidirectio (None, 1, 200)            106400
# _________________________________________________________________
# dense_103 (Dense)            (None, 1, 100)            20100
# _________________________________________________________________
# dense_104 (Dense)            (None, 1, 1)              101
# =================================================================
# Total params: 130,025
# Trainable params: 130,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit([Xtrain], Ytrain, validation_data=(Xtest,Ytest), epochs=100, shuffle=False, verbose=1)
# Out:
# Train on 8000 samples, validate on 1999 samples
# Epoch 1/100
# 8000/8000 [==============================] - 3s 339us/sample - loss: 3.9509e-04 - val_loss: 0.0606
# Epoch 2/100
# 8000/8000 [==============================] - 1s 76us/sample - loss: 7.9527e-04 - val_loss: 0.1165
# Epoch 3/100
# 8000/8000 [==============================] - 1s 74us/sample - loss: 0.0012 - val_loss: 0.1094
# Epoch 4/100
# 8000/8000 [==============================] - 1s 74us/sample - loss: 0.0016 - val_loss: 0.1282
# Epoch 5/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0020 - val_loss: 0.1219
# Epoch 6/100
# 8000/8000 [==============================] - 1s 74us/sample - loss: 0.0022 - val_loss: 0.1486
# Epoch 7/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0022 - val_loss: 0.1666
# Epoch 8/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0024 - val_loss: 0.1705
# Epoch 9/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0024 - val_loss: 0.1753
# Epoch 10/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0024 - val_loss: 0.1749
# Epoch 11/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0024 - val_loss: 0.1730
# Epoch 12/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0016 - val_loss: 0.0228
# Epoch 13/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0012 - val_loss: 0.0364
# Epoch 14/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0018 - val_loss: 0.0885
# Epoch 15/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 0.0012 - val_loss: 0.0052
# Epoch 16/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 2.0067e-04 - val_loss: 0.0039
# Epoch 17/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 5.6931e-05 - val_loss: 0.0043
# Epoch 18/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 3
100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 2.1304e-05 - val_loss: 0.0282
# Epoch 100/100
# 8000/8000 [==============================] - 1s 73us/sample - loss: 2.1473e-05 - val_loss: 0.0283

# %%
yhat.shape
# Out:
# (1999, 1, 1)

# %%
yhay=yhat.reshape(-1,1)

# %%
yhat = model.predict(Xtest)
yhat=yhat.reshape(-1,1)
pyplot.plot(yhat, label='predict')
pyplot.plot(Ytest, label='true')
pyplot.legend()
pyplot.show()

# %%
Xtest = X[k:,:,:]  
Ytest= Y[k:,:1]

# %%
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(6, 3)))
model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=128, kernel_size=1, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1))


model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_153 (Conv1D)          (None, 4, 256)            2560
# _________________________________________________________________
# conv1d_154 (Conv1D)          (None, 2, 256)            196864
# _________________________________________________________________
# conv1d_155 (Conv1D)          (None, 2, 128)            32896
# _________________________________________________________________
# max_pooling1d_71 (MaxPooling (None, 1, 128)            0
# _________________________________________________________________
# flatten_57 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_93 (Dense)             (None, 100)               12900
# _________________________________________________________________
# dense_94 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 245,321
# Trainable params: 245,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(6, 3)))
model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=128, kernel_size=1, activation='relu'))


model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(Xtrain, Ytrain,validation_data=[Xtest,Ytest], epochs=200, verbose=1)
# Out:
# Train on 8000 samples, validate on 1999 samples
# Epoch 1/200
# 8000/8000 [==============================] - 1s 108us/sample - loss: 3.0141e-04 - val_loss: 4.2438e-04
# Epoch 2/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 9.9012e-06 - val_loss: 4.3828e-04
# Epoch 3/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 8.7408e-06 - val_loss: 3.4210e-04
# Epoch 4/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 9.6906e-06 - val_loss: 3.3890e-04
# Epoch 5/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 1.0458e-05 - val_loss: 2.5959e-04
# Epoch 6/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 1.0836e-05 - val_loss: 5.8864e-04
# Epoch 7/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 9.3848e-06 - val_loss: 5.3115e-04
# Epoch 8/200
# 8000/8000 [==============================] - 1s 73us/sample - loss: 1.0375e-05 - val_loss: 3.4635e-04
# Epoch 9/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 9.9233e-06 - val_loss: 2.0112e-04
# Epoch 10/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 1.1109e-05 - val_loss: 2.2497e-04
# Epoch 11/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 8.0700e-06 - val_loss: 2.8286e-04
# Epoch 12/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 8.9352e-06 - val_loss: 2.1884e-04
# Epoch 13/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 9.7155e-06 - val_loss: 1.9167e-04
# Epoch 14/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 8.3263e-06 - val_loss: 4.0719e-04
# Epoch 15/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 9.8857e-06 - val_loss: 2.1716e-04
# Epoch 16/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 8.5387e-06 - val_loss: 2.0721e-04
# Epoch 17/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 8.4458e-06 - val_loss: 1.7878e-04
# Epoch 18/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 7.8484e-06 - val_loss: 8.7276e-04
# Epoch 19/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 7.4141e-06 - val_loss: 1.6968e-04
# Epoch 20/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 9.0990e-06 - val_loss: 2.5112e-04
# Epoch 21/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 8.9337e-06 - val_loss: 1.6320e-04
# Epoch 22/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 7.4063e-06 - val_loss: 2.1930e-04
# Epoch 23/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 7.4338e-06 - val_loss: 2.0129e-04
# Epoch 24/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 7.9083e-06 - val_loss: 2.1841e-04
# Epoch 25/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 7.8699e-06 - val_loss: 2.1312e-04
# Epoch 26/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 6.2991e-06 - val_loss: 6.1508e-04
# Epoch 27/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 7.3912e-06 - val_loss: 7.7077e-04
# Epoch 28/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 7.4370e-06 - val_loss: 5.8074e-04
# Epoch 29/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 8.5058e-06 - val_loss: 4.4816e-04
# Epoch 30/200
# 8000/8000 [==============================] - 1s 70us/sample - loss: 6.7728e-06 - val_loss: 1.7013e-04
# Epoch 31/200
# 8000/8000 [==============================] - 1s 69us/sample - loss:
200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.6753e-06 - val_loss: 1.1280e-04
# Epoch 177/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.3854e-06 - val_loss: 1.6782e-04
# Epoch 178/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.0593e-06 - val_loss: 1.1631e-04
# Epoch 179/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 5.1476e-06 - val_loss: 9.6351e-05
# Epoch 180/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.3497e-06 - val_loss: 1.0065e-04
# Epoch 181/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 4.0112e-06 - val_loss: 9.9706e-05
# Epoch 182/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 5.0324e-06 - val_loss: 9.4550e-05
# Epoch 183/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 3.9851e-06 - val_loss: 1.1727e-04
# Epoch 184/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 3.9627e-06 - val_loss: 1.1322e-04
# Epoch 185/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.3914e-06 - val_loss: 1.6185e-04
# Epoch 186/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.2719e-06 - val_loss: 1.7465e-04
# Epoch 187/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 4.4448e-06 - val_loss: 1.0124e-04
# Epoch 188/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 3.9553e-06 - val_loss: 1.8867e-04
# Epoch 189/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.0166e-06 - val_loss: 9.6657e-05
# Epoch 190/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 4.1775e-06 - val_loss: 9.7605e-05
# Epoch 191/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 3.9366e-06 - val_loss: 1.1066e-04
# Epoch 192/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.0153e-06 - val_loss: 1.6198e-04
# Epoch 193/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.2324e-06 - val_loss: 1.8814e-04
# Epoch 194/200
# 8000/8000 [==============================] - 1s 70us/sample - loss: 4.4925e-06 - val_loss: 2.9115e-04
# Epoch 195/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.6996e-06 - val_loss: 9.9413e-05
# Epoch 196/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.5178e-06 - val_loss: 1.5722e-04
# Epoch 197/200
# 8000/8000 [==============================] - 1s 68us/sample - loss: 4.3629e-06 - val_loss: 9.7602e-05
# Epoch 198/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.8546e-06 - val_loss: 9.7126e-05
# Epoch 199/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 4.6765e-06 - val_loss: 1.2723e-04
# Epoch 200/200
# 8000/8000 [==============================] - 1s 69us/sample - loss: 3.8704e-06 - val_loss: 9.8679e-05

# %%
Xtest.shape
# Out:
# (1999, 6, 4)

# %%
Ytest.shape
# Out:
# (1999, 1)

# %%
yhat = model.predict(Xtest)
pyplot.plot(yhat, label='predict')
pyplot.plot(Ytest, label='true')
pyplot.legend()
pyplot.show()

# %%
yhat_inverse = yhat*(np.max(values)-np.min(values))+np.min(values)

# %%
testY_inverse=Ytest*(np.max(values)-np.min(values))+np.min(values)

# %%
rmse = sqrt(mean_squared_error(yhat_inverse, testY_inverse))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 372.932

# %% [raw]
# preds = model.predict(Xtest)
# preds = scaler.inverse_transform(preds)
#
#
# Ytest=np.asanyarray(Ytest)
# Ytest=Ytest.reshape(-1,1)
# Ytest = scaler.inverse_transform(Ytest)
#
#
# Ytrain=np.asanyarray(Ytrain)
# Ytrain=Ytrain.reshape(-1,1)
# Ytrain = scaler.inverse_transform(Ytrain)
#
# mean_squared_error(Ytest,preds)

# %%
from math import *

sqrt(mean_squared_error(Ytest,preds))
# Out:
# 1578.815299520498

# %%
sqrt(mean_squared_error(Ytest,preds))
# Out:
# 552.5672187616634

# %%
from matplotlib import pyplot
pyplot.figure(figsize=(20,10))
pyplot.plot(Ytest)
pyplot.plot(preds, 'r')
pyplot.show()

# %%
from matplotlib import pyplot
pyplot.figure(figsize=(20,10))
pyplot.plot(Ytest)
pyplot.plot(preds, 'r')
pyplot.show()
