# %%
import pandas as pd

df=pd.read_csv('./bitcoin2000.csv',index)

# %%
df.head()
# Out:
#          time     high      low     open  volumefrom     volumeto    close  \
# 0  1576144800  7219.93  7149.15  7170.18     1536.79  11041994.81  7166.14
# 1  1576148400  7208.36  7166.03  7166.14      785.11   5654607.43  7199.79
# 2  1576152000  7222.43  7194.87  7199.79      672.46   4855213.22  7199.97
# 3  1576155600  7211.80  7187.29  7199.97      807.61   5821087.81  7201.38
# 4  1576159200  7229.22  7152.84  7201.38     1606.06  11537799.57  7173.50
#
#   conversionType conversionSymbol              timeUTC
# 0         direct              NaN  2019-12-12 19:00:00
# 1         direct              NaN  2019-12-12 20:00:00
# 2         direct              NaN  2019-12-12 21:00:00
# 3         direct              NaN  2019-12-12 22:00:00
# 4         direct              NaN  2019-12-12 23:00:00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.figure(figsize=(8,5),dpi=120)
sns.lineplot(df.index,df.close,label='BTC-USD');
# Out:
# /home/hj19/anaconda3/envs/asv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = df.drop(['conversionType','conversionSymbol','time'],axis=1)

# %%
df = df.set_index('timeUTC')

# %%
def normalize_cols(df,cols):
    """Scale the values of each feature
    according to the columns max value"""
    data = df.loc[:,cols]
    for col in cols:
        scaler = lambda x: x / data[col].max()
        data[col] = data[col].apply(scaler)
    print(data[cols].head())
    return data[cols].values

features = df.columns.values[:-1] # columns to train model on
X = normalize_cols(df,features)
# Out:
#                          high       low      open  volumefrom  volumeto
# timeUTC
# 2019-12-12 19:00:00  0.172047  0.174457  0.172814    0.006522  0.001405
# 2019-12-12 20:00:00  0.171771  0.174869  0.172716    0.003332  0.000719
# 2019-12-12 21:00:00  0.172106  0.175572  0.173527    0.002854  0.000618
# 2019-12-12 22:00:00  0.171853  0.175387  0.173532    0.003427  0.000741
# 2019-12-12 23:00:00  0.172268  0.174547  0.173566    0.006816  0.001468

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

"""
### Turn each signal into a labeled dataset
"""
window_size = 3   # num. hours per training sample
batch_size = 64   # num. of samples per epoch
buffer_size = 1000 # num of samples in memory for random selection
split_time = 8000  # where to split the data for training/validation


def window_dataset(series, window_size, batch_size, shuffle_buffer):
    """Funtion to turn time series data into set of sequences 
    where the last value is the intended output of our model"""
    ser = tf.expand_dims(series, axis=-1)
    data = tf.data.Dataset.from_tensor_slices(series)
    data = data.window(window_size + 1, shift=1, drop_remainder=True)
    data = data.flat_map(lambda w: w.batch(window_size + 1))
    data = data.shuffle(shuffle_buffer)
    data = data.map(lambda w: (w[:-1], w[1:]))
    return data.batch(batch_size).prefetch(1)


x_train = X[:split_time,:]
x_test = X[split_time:,:]

print(f"Training data shape: {x_train.shape}")
print(f"Validation data shape: {x_test.shape}")

train_set = window_dataset(x_train,window_size,batch_size,buffer_size)
# Out:
# Training data shape: (8000, 5)
# Validation data shape: (2005, 5)

# %%
keras.backend.clear_session()

"""
### Choose and connect the model components   
"""
# 1D convolution layers
conv1 = layers.Conv1D(
    filters=256,kernel_size=3,strides=1,
    padding="causal",activation="relu",
    input_shape=[None,len(features)])
conv11=layers.Conv1D(
    filters=256,kernel_size=3,strides=1,
    padding="causal",activation="relu")

conv2 = layers.Conv1D(
    filters=128,kernel_size=1,strides=1,
    padding="causal",activation="tanh")
conv22 = layers.Conv1D(
    filters=64,kernel_size=1,strides=1,
    padding="causal",activation="tanh")

# Bidirectional LSTM layers
lstm1 = layers.Bidirectional(layers.LSTM(200,return_sequences=True))
lstm11 = layers.Bidirectional(layers.LSTM(100,return_sequences=False))

lstm2 = layers.Bidirectional(layers.LSTM(100,return_sequences=True))

# Model construction
inputs = layers.Input(shape=(None,len(features)))
x = conv1(inputs)
x= conv11(x)
x = lstm1(x)
x = lstm2(x)
x = conv2(x)
x = conv2(x)

x = layers.Dense(100,activation='relu')(x)
x = layers.Dropout(.1)(x)
x = layers.Dense(1,activation='tanh')(x)
outputs = layers.Lambda(lambda x: 25*abs(x))(x)

# SGD optimizer and Huber loss
optimizer = keras.optimizers.SGD(lr=1e-5, momentum=0.9)
loss = keras.losses.Huber()

model = keras.Model(inputs=inputs,outputs=outputs)
model.compile(optimizer,loss,
              metrics=["mae"])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 5)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, None, 256)    4096        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, None, 256)    196864      conv1d[0][0]
#                                                                  conv1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, None, 400)    731200      conv1d_1[1][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, None, 200)    400800      bidirectional[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, None, 128)    25728       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 100)    12900       conv1d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 100)    0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 1)      101         dropout[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, None, 1)      0           dense_1[0][0]
# ==================================================================================================
# Total params: 1,371,689
# Trainable params: 1,371,689
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 30

history = model.fit(train_set, epochs=epochs, verbose=1)
print(f"Model trained for {epochs} epochs")
# Out:
# Epoch 1/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0077 - mae: 0.1116
# Epoch 2/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0067 - mae: 0.1071
# Epoch 3/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0066 - mae: 0.1070
# Epoch 4/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0066 - mae: 0.1071
# Epoch 5/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0065 - mae: 0.1071
# Epoch 6/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0065 - mae: 0.1070
# Epoch 7/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0065 - mae: 0.1070
# Epoch 8/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0065 - mae: 0.1070
# Epoch 9/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0065 - mae: 0.1070
# Epoch 10/30
# 43/63 [===================>..........] - ETA: 0s - loss: 0.0053 - mae: 0.0966
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-53ef88e66ea6> in <module>
#       1 epochs = 30
#       2
# ----> 3 history = model.fit(train_set, epochs=epochs, verbose=1)
#       4 print(f"Model trained for {epochs} epochs")
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/asv/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def model_forecast(model, X, window_size):
    """Takes in numpy array, creates a windowed tensor 
    and predicts the following value on each window"""
    data = tf.data.Dataset.from_tensor_slices(X)
    data = data.window(window_size, shift=1, drop_remainder=True)
    data = data.flat_map(lambda w: w.batch(window_size))
    data = data.batch(32).prefetch(1)
    forecast = model.predict(data)
    return forecast

train_window = [i for i in range(split_time-window_size)]

forecast = model_forecast(model,x_train,window_size)

plt.figure(figsize=(8,5),dpi=120)
sns.lineplot(train_window,forecast[:-1,1,0],label='Forecast')
sns.lineplot(train_window,X[:split_time-window_size,1],label='BTC-USD')
# Out:
# /home/hj19/anaconda3/envs/asv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/hj19/anaconda3/envs/asv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
"""
### Make predictions on unseen data
"""

val_window = [i for i in range(split_time,len(df)-window_size)]

forecast = model_forecast(model,x_test,window_size)

plt.figure(figsize=(8,5),dpi=120)
sns.lineplot(val_window,forecast[:-1,1,0],label='Forecast')
sns.lineplot(val_window,X[split_time:-window_size,1],label='BTC-USD')
# Out:
# /home/hj19/anaconda3/envs/asv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/hj19/anaconda3/envs/asv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
